# %% [markdown]
# ## Word2Vec

# %%
# !pip install gensim
# !pip install nltk
# Out:
# Requirement already satisfied: gensim in /usr/local/lib/python3.10/dist-packages (4.3.2)
# Requirement already satisfied: numpy>=1.18.5 in /usr/local/lib/python3.10/dist-packages (from gensim) (1.23.5)
# Requirement already satisfied: scipy>=1.7.0 in /usr/local/lib/python3.10/dist-packages (from gensim) (1.11.3)
# Requirement already satisfied: smart-open>=1.8.1 in /usr/local/lib/python3.10/dist-packages (from gensim) (6.4.0)
# Requirement already satisfied: nltk in /usr/local/lib/python3.10/dist-packages (3.8.1)
# Requirement already satisfied: click in /usr/local/lib/python3.10/dist-packages (from nltk) (8.1.7)
# Requirement already satisfied: joblib in /usr/local/lib/python3.10/dist-packages (from nltk) (1.3.2)
# Requirement already satisfied: regex>=2021.8.3 in /usr/local/lib/python3.10/dist-packages (from nltk) (2023.6.3)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from nltk) (4.66.1)

# %%
import gensim
import pandas as pd
from gensim.models import Word2Vec
from nltk.tokenize import sent_tokenize, word_tokenize
from nltk.stem import WordNetLemmatizer

# %%
import nltk
nltk.download('punkt')
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# True

# %% [markdown]
# # Downloading Text Corpus

# %%
# !pip install opendatasets --upgrade
import opendatasets as od
dataset_url = 'https://www.kaggle.com/datasets/snap/amazon-fine-food-reviews'
od.download(dataset_url)
# Out:
# Requirement already satisfied: opendatasets in /usr/local/lib/python3.10/dist-packages (0.1.22)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from opendatasets) (4.66.1)
# Requirement already satisfied: kaggle in /usr/local/lib/python3.10/dist-packages (from opendatasets) (1.5.16)
# Requirement already satisfied: click in /usr/local/lib/python3.10/dist-packages (from opendatasets) (8.1.7)
# Requirement already satisfied: six>=1.10 in /usr/local/lib/python3.10/dist-packages (from kaggle->opendatasets) (1.16.0)
# Requirement already satisfied: certifi in /usr/local/lib/python3.10/dist-packages (from kaggle->opendatasets) (2023.7.22)
# Requirement already satisfied: python-dateutil in /usr/local/lib/python3.10/dist-packages (from kaggle->opendatasets) (2.8.2)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from kaggle->opendatasets) (2.31.0)
# Requirement already satisfied: python-slugify in /usr/local/lib/python3.10/dist-packages (from kaggle->opendatasets) (8.0.1)
# Requirement already satisfied: urllib3 in /usr/local/lib/python3.10/dist-packages (from kaggle->opendatasets) (2.0.6)
# Requirement already satisfied: bleach in /usr/local/lib/python3.10/dist-packages (from kaggle->opendatasets) (6.0.0)
# Requirement already satisfied: webencodings in /usr/local/lib/python3.10/dist-packages (from bleach->kaggle->opendatasets) (0.5.1)
# Requirement already satisfied: text-unidecode>=1.3 in /usr/local/lib/python3.10/dist-packages (from python-slugify->kaggle->opendatasets) (1.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->kaggle->opendatasets) (3.3.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->kaggle->opendatasets) (3.4)
# Skipping, found downloaded files in "./amazon-fine-food-reviews" (use force=True to force download)

# %%
data=pd.read_csv("/content/amazon-fine-food-reviews/Reviews.csv")

# %%
data
# Out:
#             Id   ProductId          UserId                      ProfileName  \
# 0            1  B001E4KFG0  A3SGXH7AUHU8GW                       delmartian
# 1            2  B00813GRG4  A1D87F6ZCVE5NK                           dll pa
# 2            3  B000LQOCH0   ABXLMWJIXXAIN  Natalia Corres "Natalia Corres"
# 3            4  B000UA0QIQ  A395BORC6FGVXV                             Karl
# 4            5  B006K2ZZ7K  A1UQRSCLF8GW1T    Michael D. Bigham "M. Wassir"
# ...        ...         ...             ...                              ...
# 568449  568450  B001EO7N10  A28KG5XORO54AY                 Lettie D. Carter
# 568450  568451  B003S1WTCU  A3I8AFVPEE8KI5                        R. Sawyer
# 568451  568452  B004I613EE  A121AA1GQV751Z                    pksd "pk_007"
# 568452  568453  B004I613EE   A3IBEVCTXKNOH          Kathy A. Welch "katwel"
# 568453  568454  B001LR2CU2  A3LGQPJCZVL9UC                         srfell17
#
#         HelpfulnessNumerator  HelpfulnessDenominator  Score        Time  \
# 0                          1                       1      5  1303862400
# 1                          0                       0      1  1346976000
# 2                          1                       1      4  1219017600
# 3                          3                       3      2  1307923200
# 4                          0                       0      5  1350777600
# ...                      ...                     ...    ...         ...
# 568449                     0                       0      5  1299628800
# 568450                     0                       0      2  1331251200
# 568451                     2                       2      5  1329782400
# 568452                     1                       1      5  1331596800
# 568453                     0                       0      5  1338422400
#
#                                    Summary  \
# 0                    Good Quality Dog Food
# 1                        Not as Advertised
# 2                    "Delight" says it all
# 3                           Cough Medicine
# 4                              Great taffy
# ...                                    ...
# 568449                 Will not do without
# 568450                        disappointed
# 568451            Perfect for our maltipoo
# 568452  Favorite Training and reward treat
# 568453                         Great Honey
#
#                                                      Text
# 0       I have bought several of the Vitality canned d...
# 1       Product arrived labeled as Jumbo Salted Peanut...
# 2       This is a confection that has been around a fe...
# 3       If you are looking for the secret ingredient i...
# 4       Great taffy at a great price.  There was a wid...
# ...                                                   ...
# 568449  Great for sesame chicken..this is a good if no...
# 568450  I'm disappointed with the flavor. The chocolat...
# 568451  These stars are small, so you can give 10-15 o...
# 568452  These are the BEST treats for training and rew...
# 568453  I am very satisfied ,product is as advertised,...
#
# [568454 rows x 10 columns]

# %%
corpus_text = '\n'.join(data[:50000]['Text'])
lemmatizer = WordNetLemmatizer()

# %%
t_data=[]
for i in sent_tokenize(corpus_text):
  temp=[]
  tokens=word_tokenize(i)
  lemmatized_tokens=[lemmatizer.lemmatize(token) for token in tokens]
  for j in lemmatized_tokens:
    if(j.isalnum()):
      temp.append(j.lower())
  t_data.append(temp)

# %%
t_data
# Out:
# [['i',
#   'have',
#   'bought',
#   'several',
#   'of',
#   'the',
#   'vitality',
#   'canned',
#   'dog',
#   'food',
#   'product',
#   'and',
#   'have',
#   'found',
#   'them',
#   'all',
#   'to',
#   'be',
#   'of',
#   'good',
#   'quality'],
#  ['the',
#   'product',
#   'look',
#   'more',
#   'like',
#   'a',
#   'stew',
#   'than',
#   'a',
#   'processed',
#   'meat',
#   'and',
#   'it',
#   'smell',
#   'better'],
#  ['my',
#   'labrador',
#   'is',
#   'finicky',
#   'and',
#   'she',
#   'appreciates',
#   'this',
#   'product',
#   'better',
#   'than',
#   'most'],
#  ['product',
#   'arrived',
#   'labeled',
#   'a',
#   'jumbo',
#   'salted',
#   'peanuts',
#   'the',
#   'peanut',
#   'were',
#   'actually',
#   'small',
#   'sized',
#   'unsalted'],
#  ['not',
#   'sure',
#   'if',
#   'this',
#   'wa',
#   'an',
#   'error',
#   'or',
#   'if',
#   'the',
#   'vendor',
#   'intended',
#   'to',
#   'represent',
#   'the',
#   'product',
#   'a',
#   'jumbo'],
#  ['this',
#   'is',
#   'a',
#   'confection',
#   'that',
#   'ha',
#   'been',
#   'around',
#   'a',
#   'few',
#   'century'],
#  ['it',
#   'is',
#   'a',
#   'light',
#   'pillowy',
#   'citrus',
#   'gelatin',
#   'with',
#   'nut',
#   'in',
#   'this',
#   'case',
#   'filberts'],
#  ['and',
#   'it',
#   'is',
#   'cut',
#   'into',
#   'tiny',
#   'square',
#   'and',
#   'then',
#   'liberally',
#   'coated',
#   'with',
#   'powdered',
#   'sugar'],
#  ['and', 'it', 'is', 'a', 'tiny', 'mouthful', 'of', 'heaven'],
#  ['not', 'too', 'chewy', 'and', 'very', 'flavorful'],
#  ['i', 'highly', 'recommend', 'this', 'yummy', 'treat'],
#  ['if', 'you', 'are', 'familiar', 'with', 'the', 'story', 'of'],
#  ['lewis',
#   'the',
#   'lion',
#   'the',
#   'witch',
#   'and',
#   'the',
#   'wardrobe',
#   'this',
#   'is',
#   'the',
#   'treat',
#   'that',
#   'seduces',
#   'edmund',
#   'into',
#   'selling',
#   'out',
#   'his',
#   'brother',
#   'and',
#   'sisters',
#   'to',
#   'the',
#   'witch'],
#  ['if',
#   'you',
#   'are',
#   'looking',
#   'for',
#   'the',
#   'secret',
#   'ingredient',
#   'in',
#   'robitussin',
#   'i',
#   'believe',
#   'i',
#   'have',
#   'found',
#   'it'],
#  ['i',
#   'got',
#   'this',
#   'in',
#   'addition',
#   'to',
#   'the',
#   'root',
#   'beer',
#   'extract',
#   'i',
#   'ordered',
#   'which',
#   'wa',
#   'good',
#   'and',
#   'made',
#   'some',
#   'cherry',
#   'soda'],
#  ['the', 'flavor', 'is', 'very', 'medicinal'],
#  ['great', 'taffy', 'at', 'a', 'great', 'price'],
#  ['there', 'wa', 'a', 'wide', 'assortment', 'of', 'yummy', 'taffy'],
#  ['delivery', 'wa', 'very', 'quick'],
#  ['if', 'your', 'a', 'taffy', 'lover', 'this', 'is', 'a', 'deal'],
#  ['i',
#   'got',
#   'a',
#   'wild',
#   'hair',
#   'for',
#   'taffy',
#   'and',
#   'ordered',
#   'this',
#   'five',
#   'pound',
#   'bag'],
#  ['the',
#   'taffy',
#   'wa',
#   'all',
#   'very',
#   'enjoyable',
#   'with',
#   'many',
#   'flavor',
#   'watermelon',
#   'root',
#   'beer',
#   'melon',
#   'peppermint',
#   'grape',
#   'etc'],
#  ['my',
#   'only',
#   'complaint',
#   'is',
#   'there',
#   'wa',
#   'a',
#   'bit',
#   'too',
#   'much',
#   'piece',
#   'just',
#   'not',
#   'my',
#   'particular',
#   'favorite'],
#  ['between',
#   'me',
#   'my',
#   'kid',
#   'and',
#   'my',
#   'husband',
#   'this',
#   'lasted',
#   'only',
#   'two',
#   'week'],
#  ['i',
#   'would',
#   'recommend',
#   'this',
#   'brand',
#   'of',
#   'taffy',
#   'it',
#   'wa',
#   'a',
#   'delightful',
#   'treat'],
#  ['this',
#   'saltwater',
#   'taffy',
#   'had',
#   'great',
#   'flavor',
#   'and',
#   'wa',
#   'very',
#   'soft',
#   'and',
#   'chewy'],
#  ['each', 'candy', 'wa', 'individually', 'wrapped', 'well'],
#  ['none',
#   'of',
#   'the',
#   'candy',
#   'were',
#   'stuck',
#   'together',
#   'which',
#   'did',
#   'happen',
#   'in',
#   'the',
#   'expensive',
#   'version',
#   'fralinger'],
#  ['would', 'highly', 'recommend', 'this', 'candy'],
#  ['i', 'served', 'it', 'at', 'a', 'party', 'and', 'everyone', 'loved', 'it'],
#  ['this', 'taffy', 'is', 'so', 'good'],
#  ['it', 'is', 'very', 'soft', 'and', 'chewy'],
#  ['the', 'flavor', 'are', 'amazing'],
#  ['i', 'would', 'definitely', 'recommend', 'you', 'buying', 'it'],
#  ['very', 'satisfying'],
#  ['right',
#   'now',
#   'i',
#   'mostly',
#   'just',
#   'sprouting',
#   'this',
#   'so',
#   'my',
#   'cat',
#   'can',
#   'eat',
#   'the',
#   'grass'],
#  ['they', 'love', 'it'],
#  ['i',
#   'rotate',
#   'it',
#   'around',
#   'with',
#   'wheatgrass',
#   'and',
#   'rye',
#   'too',
#   'this',
#   'is',
#   'a',
#   'very',
#   'healthy',
#   'dog',
#   'food'],
#  ['good', 'for', 'their', 'digestion'],
#  ['also', 'good', 'for', 'small', 'puppy'],
#  ['my', 'dog', 'eats', 'her', 'required', 'amount', 'at', 'every', 'feeding'],
#  ['i',
#   'do',
#   'know',
#   'if',
#   'it',
#   'the',
#   'cactus',
#   'or',
#   'the',
#   'tequila',
#   'or',
#   'just',
#   'the',
#   'unique',
#   'combination',
#   'of',
#   'ingredient',
#   'but',
#   'the',
#   'flavour',
#   'of',
#   'this',
#   'hot',
#   'sauce',
#   'make',
#   'it',
#   'one',
#   'of',
#   'a',
#   'kind'],
#  ['we',
#   'picked',
#   'up',
#   'a',
#   'bottle',
#   'once',
#   'on',
#   'a',
#   'trip',
#   'we',
#   'were',
#   'on',
#   'and',
#   'brought',
#   'it',
#   'back',
#   'home',
#   'with',
#   'u',
#   'and',
#   'were',
#   'totally',
#   'blown',
#   'away'],
#  ['when',
#   'we',
#   'realized',
#   'that',
#   'we',
#   'simply',
#   'could',
#   'find',
#   'it',
#   'anywhere',
#   'in',
#   'our',
#   'city',
#   'we',
#   'were',
#   'br',
#   'br',
#   'now',
#   'because',
#   'of',
#   'the',
#   'magic',
#   'of',
#   'the',
#   'internet',
#   'we',
#   'have',
#   'a',
#   'case',
#   'of',
#   'the',
#   'sauce',
#   'and',
#   'are',
#   'ecstatic',
#   'because',
#   'of',
#   'br',
#   'br',
#   'if',
#   'you',
#   'love',
#   'hot',
#   'sauce',
#   'i',
#   'mean',
#   'really',
#   'love',
#   'hot',
#   'sauce',
#   'but',
#   'do',
#   'want',
#   'a',
#   'sauce',
#   'that',
#   'tastelessly',
#   'burn',
#   'your',
#   'throat',
#   'grab',
#   'a',
#   'bottle',
#   'of',
#   'tequila',
#   'picante',
#   'gourmet',
#   'de',
#   'inclan'],
#  ['just',
#   'realize',
#   'that',
#   'once',
#   'you',
#   'taste',
#   'it',
#   'you',
#   'will',
#   'never',
#   'want',
#   'to',
#   'use',
#   'any',
#   'other',
#   'br',
#   'br',
#   'thank',
#   'you',
#   'for',
#   'the',
#   'personal',
#   'incredible',
#   'service'],
#  ['one',
#   'of',
#   'my',
#   'boy',
#   'needed',
#   'to',
#   'lose',
#   'some',
#   'weight',
#   'and',
#   'the',
#   'other',
#   'did'],
#  ['i',
#   'put',
#   'this',
#   'food',
#   'on',
#   'the',
#   'floor',
#   'for',
#   'the',
#   'chubby',
#   'guy',
#   'and',
#   'the',
#   'no',
#   'food',
#   'up',
#   'higher',
#   'where',
#   'only',
#   'my',
#   'skinny',
#   'boy',
#   'can',
#   'jump'],
#  ['the', 'higher', 'food', 'sits', 'going', 'stale'],
#  ['they', 'both', 'really', 'go', 'for', 'this', 'food'],
#  ['and',
#   'my',
#   'chubby',
#   'boy',
#   'ha',
#   'been',
#   'losing',
#   'about',
#   'an',
#   'ounce',
#   'a',
#   'week'],
#  ['my',
#   'cat',
#   'have',
#   'been',
#   'happily',
#   'eating',
#   'felidae',
#   'platinum',
#   'for',
#   'more',
#   'than',
#   'two',
#   'year'],
#  ['i',
#   'just',
#   'got',
#   'a',
#   'new',
#   'bag',
#   'and',
#   'the',
#   'shape',
#   'of',
#   'the',
#   'food',
#   'is',
#   'different'],
#  ['they',
#   'tried',
#   'the',
#   'new',
#   'food',
#   'when',
#   'i',
#   'first',
#   'put',
#   'it',
#   'in',
#   'their',
#   'bowl',
#   'and',
#   'now',
#   'the',
#   'bowl',
#   'sit',
#   'full',
#   'and',
#   'the',
#   'kitty',
#   'will',
#   'not',
#   'touch',
#   'the',
#   'food'],
#  ['i',
#   'noticed',
#   'similar',
#   'review',
#   'related',
#   'to',
#   'formula',
#   'change',
#   'in',
#   'the',
#   'past'],
#  ['unfortunately',
#   'i',
#   'now',
#   'need',
#   'to',
#   'find',
#   'a',
#   'new',
#   'food',
#   'that',
#   'my',
#   'cat',
#   'will',
#   'eat'],
#  ['good', 'flavor'],
#  ['these',
#   'came',
#   'securely',
#   'packed',
#   'they',
#   'were',
#   'fresh',
#   'and',
#   'delicious'],
#  ['i', 'love', 'these', 'twizzlers'],
#  ['the',
#   'strawberry',
#   'twizzlers',
#   'are',
#   'my',
#   'guilty',
#   'pleasure',
#   'yummy'],
#  ['six',
#   'pound',
#   'will',
#   'be',
#   'around',
#   'for',
#   'a',
#   'while',
#   'with',
#   'my',
#   'son',
#   'and',
#   'i'],
#  ['my',
#   'daughter',
#   'love',
#   'twizzlers',
#   'and',
#   'this',
#   'shipment',
#   'of',
#   'six',
#   'pound',
#   'really',
#   'hit',
#   'the',
#   'spot'],
#  ['it',
#   'exactly',
#   'what',
#   'you',
#   'would',
#   'expect',
#   'six',
#   'package',
#   'of',
#   'strawberry',
#   'twizzlers'],
#  ['i',
#   'love',
#   'eating',
#   'them',
#   'and',
#   'they',
#   'are',
#   'good',
#   'for',
#   'watching',
#   'tv',
#   'and',
#   'looking',
#   'at',
#   'movie'],
#  ['it', 'is', 'not', 'too', 'sweet'],
#  ['i',
#   'like',
#   'to',
#   'transfer',
#   'them',
#   'to',
#   'a',
#   'zip',
#   'lock',
#   'baggie',
#   'so',
#   'they',
#   'stay',
#   'fresh',
#   'so',
#   'i',
#   'can',
#   'take',
#   'my',
#   'time',
#   'eating',
#   'them'],
#  ['i', 'am', 'very', 'satisfied', 'with', 'my', 'twizzler', 'purchase'],
#  ['i',
#   'shared',
#   'these',
#   'with',
#   'others',
#   'and',
#   'we',
#   'have',
#   'all',
#   'enjoyed',
#   'them'],
#  ['i', 'will', 'definitely', 'be', 'ordering', 'more'],
#  ['twizzlers',
#   'strawberry',
#   'my',
#   'childhood',
#   'favorite',
#   'candy',
#   'made',
#   'in',
#   'lancaster',
#   'pennsylvania',
#   'by',
#   'y',
#   's',
#   'candies',
#   'one',
#   'of',
#   'the',
#   'oldest',
#   'confectionery',
#   'firms',
#   'in',
#   'the',
#   'united',
#   'states',
#   'now',
#   'a',
#   'subsidiary',
#   'of',
#   'the',
#   'hershey',
#   'company',
#   'the',
#   'company',
#   'wa',
#   'established',
#   'in',
#   '1845',
#   'a',
#   'young',
#   'and',
#   'smylie',
#   'they',
#   'also',
#   'make',
#   'apple',
#   'licorice',
#   'twists',
#   'green',
#   'color',
#   'and',
#   'blue',
#   'raspberry',
#   'licorice',
#   'twists',
#   'i',
#   'like',
#   'them',
#   'all',
#   'br',
#   'br',
#   'i',
#   'keep',
#   'it',
#   'in',
#   'a',
#   'dry',
#   'cool',
#   'place',
#   'because',
#   'is',
#   'not',
#   'recommended',
#   'it',
#   'to',
#   'put',
#   'it',
#   'in',
#   'the',
#   'fridge'],
#  ['according',
#   'to',
#   'the',
#   'guinness',
#   'book',
#   'of',
#   'records',
#   'the',
#   'longest',
#   'licorice',
#   'twist',
#   'ever',
#   'made',
#   'measured',
#   'feet',
#   '370',
#   'm',
#   'and',
#   'weighted',
#   '100',
#   'pounds',
#   '45',
#   'kg',
#   'and',
#   'wa',
#   'made',
#   'by',
#   'y',
#   's',
#   'candies',
#   'inc'],
#  ['this',
#   'twist',
#   'became',
#   'a',
#   'guinness',
#   'world',
#   'record',
#   'on',
#   'july',
#   '19',
#   '1998'],
#  ['this', 'product', 'is', 'kosher'],
#  ['thank',
#   'you',
#   'candy',
#   'wa',
#   'delivered',
#   'very',
#   'fast',
#   'and',
#   'wa',
#   'purchased',
#   'at',
#   'a',
#   'reasonable',
#   'price'],
#  ['i',
#   'wa',
#   'home',
#   'bound',
#   'and',
#   'unable',
#   'to',
#   'get',
#   'to',
#   'a',
#   'store',
#   'so',
#   'this',
#   'wa',
#   'perfect',
#   'for',
#   'me'],
#  ['my', 'husband', 'is', 'a', 'twizzlers', 'addict'],
#  ['we',
#   'bought',
#   'these',
#   'many',
#   'time',
#   'from',
#   'amazon',
#   'because',
#   'we',
#   'government',
#   'employee',
#   'living',
#   'overseas',
#   'and',
#   'ca',
#   'get',
#   'them',
#   'in',
#   'the',
#   'country',
#   'we',
#   'are',
#   'assigned',
#   'to'],
#  ['they',
#   'always',
#   'been',
#   'fresh',
#   'and',
#   'tasty',
#   'packed',
#   'well',
#   'and',
#   'arrive',
#   'in',
#   'a',
#   'timely',
#   'manner'],
#  ['i',
#   'bought',
#   'these',
#   'for',
#   'my',
#   'husband',
#   'who',
#   'is',
#   'currently',
#   'overseas'],
#  ['he',
#   'love',
#   'these',
#   'and',
#   'apparently',
#   'his',
#   'staff',
#   'like',
#   'them',
#   'br',
#   'there',
#   'are',
#   'generous',
#   'amount',
#   'of',
#   'twizzlers',
#   'in',
#   'each',
#   'bag',
#   'and',
#   'this',
#   'wa',
#   'well',
#   'worth',
#   'the',
#   'price'],
#  ['a',
#   'http',
#   'twizzlers',
#   'strawberry',
#   'bags',
#   'pack',
#   'of',
#   '6',
#   'i',
#   'can',
#   'remember',
#   'buying',
#   'this',
#   'candy',
#   'a',
#   'a',
#   'kid',
#   'and',
#   'the',
#   'quality',
#   'ha',
#   'dropped',
#   'in',
#   'all',
#   'these',
#   'year'],
#  ['still',
#   'a',
#   'superb',
#   'product',
#   'you',
#   'wo',
#   'be',
#   'disappointed',
#   'with'],
#  ['i', 'love', 'this', 'candy'],
#  ['after',
#   'weight',
#   'watcher',
#   'i',
#   'had',
#   'to',
#   'cut',
#   'back',
#   'but',
#   'still',
#   'have',
#   'a',
#   'craving',
#   'for',
#   'it'],
#  ['i',
#   'have',
#   'lived',
#   'out',
#   'of',
#   'the',
#   'us',
#   'for',
#   'over',
#   '7',
#   'yr',
#   'now',
#   'and',
#   'i',
#   'so',
#   'miss',
#   'my',
#   'twizzlers'],
#  ['when',
#   'i',
#   'go',
#   'back',
#   'to',
#   'visit',
#   'or',
#   'someone',
#   'visit',
#   'me',
#   'i',
#   'always',
#   'stock',
#   'up'],
#  ['all',
#   'i',
#   'can',
#   'say',
#   'is',
#   'yum',
#   'br',
#   'sell',
#   'these',
#   'in',
#   'mexico',
#   'and',
#   'you',
#   'will',
#   'have',
#   'a',
#   'faithful',
#   'buyer',
#   'more',
#   'often',
#   'than',
#   'i',
#   'able',
#   'to',
#   'buy',
#   'them',
#   'right',
#   'now'],
#  ['product',
#   'received',
#   'is',
#   'a',
#   'br',
#   'br',
#   'a',
#   'http',
#   'twizzlers',
#   'strawberry',
#   'bags',
#   'pack',
#   'of',
#   '6',
#   'the',
#   'candy',
#   'is',
#   'just',
#   'red',
#   'no',
#   'flavor'],
#  ['just', 'plan', 'and', 'chewy'],
#  ['i',
#   'would',
#   'never',
#   'buy',
#   'them',
#   'again',
#   'i',
#   'wa',
#   'so',
#   'glad',
#   'amazon',
#   'carried',
#   'these',
#   'battery'],
#  ['i',
#   'have',
#   'a',
#   'hard',
#   'time',
#   'finding',
#   'them',
#   'elsewhere',
#   'because',
#   'they',
#   'are',
#   'such',
#   'a',
#   'unique',
#   'size'],
#  ['i',
#   'need',
#   'them',
#   'for',
#   'my',
#   'garage',
#   'door',
#   'br',
#   'great',
#   'deal',
#   'for',
#   'the',
#   'price'],
#  ['i',
#   'got',
#   'this',
#   'for',
#   'my',
#   'mum',
#   'who',
#   'is',
#   'not',
#   'diabetic',
#   'but',
#   'need',
#   'to',
#   'watch',
#   'her',
#   'sugar',
#   'intake',
#   'and',
#   'my',
#   'father',
#   'who',
#   'simply',
#   'chooses',
#   'to',
#   'limit',
#   'unnecessary',
#   'sugar',
#   'intake',
#   'she',
#   'the',
#   'one',
#   'with',
#   'the',
#   'sweet',
#   'tooth',
#   'they',
#   'both',
#   'loved',
#   'these',
#   'toffee',
#   'you',
#   'would',
#   'never',
#   'guess',
#   'that',
#   'they',
#   'and',
#   'it',
#   'so',
#   'great',
#   'that',
#   'you',
#   'can',
#   'eat',
#   'them',
#   'pretty',
#   'much',
#   'guilt',
#   'free'],
#  ['i',
#   'wa',
#   'so',
#   'impressed',
#   'that',
#   'i',
#   'ordered',
#   'some',
#   'for',
#   'myself',
#   'w',
#   'dark',
#   'chocolate',
#   'to',
#   'take',
#   'to',
#   'the',
#   'office',
#   'so',
#   'i',
#   'eat',
#   'them',
#   'instead',
#   'of',
#   'snacking',
#   'on',
#   'sugary',
#   'br',
#   'these',
#   'are',
#   'just',
#   'excellent'],
#  ['i',
#   'do',
#   'know',
#   'if',
#   'it',
#   'the',
#   'cactus',
#   'or',
#   'the',
#   'tequila',
#   'or',
#   'just',
#   'the',
#   'unique',
#   'combination',
#   'of',
#   'ingredient',
#   'but',
#   'the',
#   'flavour',
#   'of',
#   'this',
#   'hot',
#   'sauce',
#   'make',
#   'it',
#   'one',
#   'of',
#   'a',
#   'kind'],
#  ['we',
#   'picked',
#   'up',
#   'a',
#   'bottle',
#   'once',
#   'on',
#   'a',
#   'trip',
#   'we',
#   'were',
#   'on',
#   'and',
#   'brought',
#   'it',
#   'back',
#   'home',
#   'with',
#   'u',
#   'and',
#   'were',
#   'totally',
#   'blown',
#   'away'],
#  ['when',
#   'we',
#   'realized',
#   'that',
#   'we',
#   'simply',
#   'could',
#   'find',
#   'it',
#   'anywhere',
#   'in',
#   'our',
#   'city',
#   'we',
#   'were',
#   'br',
#   'br',
#   'now',
#   'because',
#   'of',
#   'the',
#   'magic',
#   'of',
#   'the',
#   'internet',
#   'we',
#   'have',
#   'a',
#   'case',
#   'of',
#   'the',
#   'sauce',
#   'and',
#   'are',
#   'ecstatic',
#   'because',
#   'of',
#   'br',
#   'br',
#   'if',
#   'you',
#   'love',
#   'hot',
#   'sauce',
#   'i',
#   'mean',
#   'really',
#   'love',
#   'hot',
#   'sauce',
#   'but',
#   'do',
#   'want',
#   'a',
#   'sauce',
#   'that',
#   'tastelessly',
#   'burn',
#   'your',
#   'throat',
#   'grab',
#   'a',
#   'bottle',
#   'of',
#   'tequila',
#   'picante',
#   'gourmet',
#   'de',
#   'inclan'],
#  ['just',
#   'realize',
#   'that',
#   'once',
#   'you',
#   'taste',
#   'it',
#   'you',
#   'will',
#   'never',
#   'want',
#   'to',
#   'use',
#   'any',
#   'other',
#   'br',
#   'br',
#   'thank',
#   'you',
#   'for',
#   'the',
#   'personal',
#   'incredible',
#   'service'],
#  ['i', 'have', 'never', 'been', 'a', 'huge', 'coffee', 'fan'],
#  ['however',
#   'my',
#   'mother',
#   'purchased',
#   'this',
#   'little',
#   'machine',
#   'and',
#   'talked',
#   'me',
#   'into',
#   'trying',
#   'the',
#   'latte',
#   'macciato'],
#  ['no',
#   'coffee',
#   'shop',
#   'ha',
#   'a',
#   'better',
#   'one',
#   'and',
#   'i',
#   'like',
#   'most',
#   'of',
#   'the',
#   'other',
#   'product',
#   'too',
#   'a',
#   'a',
#   'usually',
#   'drinker'],
#  ['br',
#   'the',
#   'little',
#   'dolche',
#   'guesto',
#   'machine',
#   'is',
#   'super',
#   'easy',
#   'to',
#   'use',
#   'and',
#   'prepares',
#   'a',
#   'really',
#   'good',
#   'in',
#   'le',
#   'than',
#   'a',
#   'minute',
#   'if',
#   'water',
#   'is',
#   'heated',
#   'up'],
#  ['i', 'would', 'recommend', 'the', 'dolce', 'gusto', 'to', 'anyone'],
#  ['too', 'good', 'for', 'the', 'price', 'and', 'getting', 'one', 'myself'],
#  ['this',
#   'offer',
#   'is',
#   'a',
#   'great',
#   'price',
#   'and',
#   'a',
#   'great',
#   'taste',
#   'thanks',
#   'amazon',
#   'for',
#   'selling',
#   'this',
#   'br',
#   'br',
#   'staral',
#   'mccann',
#   'instant',
#   'oatmeal',
#   'is',
#   'great',
#   'if',
#   'you',
#   'must',
#   'have',
#   'your',
#   'oatmeal',
#   'but',
#   'can',
#   'only',
#   'scrape',
#   'together',
#   'two',
#   'or',
#   'three',
#   'minute',
#   'to',
#   'prepare',
#   'it'],
#  ['there',
#   'is',
#   'no',
#   'escaping',
#   'the',
#   'fact',
#   'however',
#   'that',
#   'even',
#   'the',
#   'best',
#   'instant',
#   'oatmeal',
#   'is',
#   'nowhere',
#   'near',
#   'a',
#   'good',
#   'a',
#   'even',
#   'a',
#   'store',
#   'brand',
#   'of',
#   'oatmeal',
#   'requiring',
#   'stovetop',
#   'preparation'],
#  ['still',
#   'the',
#   'mccann',
#   'is',
#   'a',
#   'good',
#   'a',
#   'it',
#   'get',
#   'for',
#   'instant',
#   'oatmeal'],
#  ['it',
#   'even',
#   'better',
#   'than',
#   'the',
#   'organic',
#   'brand',
#   'i',
#   'have',
#   'tried'],
#  ['all',
#   'the',
#   'variety',
#   'in',
#   'the',
#   'mccann',
#   'variety',
#   'pack',
#   'taste',
#   'good'],
#  ['it',
#   'can',
#   'be',
#   'prepared',
#   'in',
#   'the',
#   'microwave',
#   'or',
#   'by',
#   'adding',
#   'boiling',
#   'water',
#   'so',
#   'it',
#   'is',
#   'convenient',
#   'in',
#   'the',
#   'extreme',
#   'when',
#   'time',
#   'is',
#   'an',
#   'br',
#   'br',
#   'mccann',
#   'use',
#   'of',
#   'actual',
#   'cane',
#   'sugar',
#   'instead',
#   'of',
#   'high',
#   'fructose',
#   'corn',
#   'syrup',
#   'helped',
#   'me',
#   'decide',
#   'to',
#   'buy',
#   'this',
#   'product'],
#  ['real',
#   'sugar',
#   'taste',
#   'better',
#   'and',
#   'is',
#   'not',
#   'a',
#   'harmful',
#   'a',
#   'the',
#   'other',
#   'stuff'],
#  ['one',
#   'thing',
#   'i',
#   'do',
#   'not',
#   'like',
#   'though',
#   'is',
#   'mccann',
#   'use',
#   'of',
#   'thickener'],
#  ['oats',
#   'plus',
#   'water',
#   'plus',
#   'heat',
#   'should',
#   'make',
#   'a',
#   'creamy',
#   'tasty',
#   'oatmeal',
#   'without',
#   'the',
#   'need',
#   'for',
#   'guar',
#   'gum'],
#  ['but', 'this', 'is', 'a', 'convenience', 'product'],
#  ['maybe',
#   'the',
#   'guar',
#   'gum',
#   'is',
#   'why',
#   'after',
#   'sitting',
#   'in',
#   'the',
#   'bowl',
#   'a',
#   'while',
#   'the',
#   'instant',
#   'mccann',
#   'becomes',
#   'too',
#   'thick',
#   'and',
#   'gluey'],
#  ['this',
#   'is',
#   'a',
#   'good',
#   'instant',
#   'oatmeal',
#   'from',
#   'the',
#   'best',
#   'oatmeal',
#   'brand'],
#  ['it',
#   'us',
#   'cane',
#   'sugar',
#   'instead',
#   'of',
#   'high',
#   'fructouse',
#   'corn',
#   'syrup',
#   'so',
#   'not',
#   'only',
#   'doe',
#   'it',
#   'have',
#   'a',
#   'better',
#   'sweetness',
#   'but',
#   'some',
#   'doctor',
#   'now',
#   'say',
#   'that',
#   'this',
#   'form',
#   'of',
#   'sugar',
#   'is',
#   'better',
#   'for',
#   'you'],
#  ['great',
#   'on',
#   'a',
#   'cold',
#   'morning',
#   'when',
#   'you',
#   'do',
#   'have',
#   'time',
#   'to',
#   'make',
#   'mccann',
#   'steel',
#   'cut',
#   'oats'],
#  ['the',
#   'apple',
#   'cinnamon',
#   'is',
#   'the',
#   'best',
#   'but',
#   'the',
#   'maple',
#   'and',
#   'brown',
#   'sugar',
#   'or',
#   'the',
#   'regular',
#   'are',
#   'good',
#   'too'],
#  ['plus',
#   'they',
#   'do',
#   'require',
#   'doctoring',
#   'to',
#   'actually',
#   'tell',
#   'the',
#   'three',
#   'flavor',
#   'apart'],
#  ['instant',
#   'oatmeal',
#   'can',
#   'become',
#   'soggy',
#   'the',
#   'minute',
#   'the',
#   'water',
#   'hit',
#   'the',
#   'bowl'],
#  ['mccann',
#   'instant',
#   'oatmeal',
#   'hold',
#   'it',
#   'texture',
#   'ha',
#   'excellent',
#   'flavor',
#   'and',
#   'is',
#   'good',
#   'for',
#   'you',
#   'all',
#   'at',
#   'the',
#   'same',
#   'time'],
#  ['mccann',
#   'regular',
#   'oat',
#   'meal',
#   'is',
#   'excellent',
#   'too',
#   'but',
#   'may',
#   'take',
#   'a',
#   'bit',
#   'longer',
#   'to',
#   'prepare',
#   'than',
#   'most',
#   'have',
#   'time',
#   'for',
#   'in',
#   'the',
#   'morning'],
#  ['this',
#   'is',
#   'the',
#   'best',
#   'instant',
#   'brand',
#   'i',
#   'ever',
#   'eaten',
#   'and',
#   'a',
#   'very',
#   'close',
#   'second',
#   'to',
#   'the',
#   'br',
#   'br',
#   'mccann',
#   'instant',
#   'irish',
#   'oatmeal',
#   'variety',
#   'pack',
#   'of',
#   'regular',
#   'apples',
#   'cinnamon',
#   'and',
#   'maple',
#   'brown',
#   'sugar',
#   'boxes',
#   'pack',
#   'of',
#   '6',
#   'mccann',
#   'instant',
#   'irish',
#   'oatmeal',
#   'variety',
#   'pack',
#   'of',
#   'regular',
#   'apples',
#   'cinnamon',
#   'and',
#   'maple',
#   'brown',
#   'sugar',
#   'boxes',
#   'pack',
#   'of',
#   '6',
#   'br',
#   'br',
#   'i',
#   'a',
#   'fan',
#   'of',
#   'the',
#   'mccann',
#   'oat',
#   'so',
#   'i',
#   'thought',
#   'i',
#   'give',
#   'the',
#   'instant',
#   'variety',
#   'a',
#   'try'],
#  ['i',
#   'found',
#   'it',
#   'to',
#   'be',
#   'a',
#   'hardy',
#   'meal',
#   'not',
#   'too',
#   'sweet',
#   'and',
#   'great',
#   'for',
#   'folk',
#   'like',
#   'me',
#   'surgery',
#   'who',
#   'need',
#   'food',
#   'that',
#   'is',
#   'palatable',
#   'easily',
#   'digestible',
#   'with',
#   'fiber',
#   'but',
#   'wo',
#   'make',
#   'you',
#   'bloat'],
#  ['for',
#   'those',
#   'of',
#   'u',
#   'with',
#   'celiac',
#   'disease',
#   'this',
#   'product',
#   'is',
#   'a',
#   'lifesaver',
#   'and',
#   'what',
#   'could',
#   'be',
#   'better',
#   'than',
#   'getting',
#   'it',
#   'at',
#   'almost',
#   'half',
#   'the',
#   'price',
#   'of',
#   'the',
#   'grocery',
#   'or',
#   'health',
#   'food',
#   'store'],
#  ['i', 'love', 'mccann', 'instant', 'oatmeal', 'all', 'flavor'],
#  ['br',
#   'br',
#   'thanks',
#   'br',
#   'abby',
#   'what',
#   'else',
#   'do',
#   'you',
#   'need',
#   'to',
#   'know'],
#  ['oatmeal',
#   'instant',
#   'make',
#   'it',
#   'with',
#   'a',
#   'half',
#   'cup',
#   'of',
#   'milk',
#   'and',
#   'add',
#   'raisin',
#   'nuke',
#   'for',
#   '90',
#   'second'],
#  ['more',
#   'expensive',
#   'than',
#   'kroger',
#   'store',
#   'brand',
#   'oatmeal',
#   'and',
#   'maybe',
#   'a',
#   'little',
#   'tastier',
#   'or',
#   'better',
#   'texture',
#   'or',
#   'something'],
#  ['it', 'still', 'just', 'oatmeal'],
#  ['mmm', 'convenient'],
#  ['i',
#   'was',
#   'visiting',
#   'my',
#   'friend',
#   'nate',
#   'the',
#   'other',
#   'morning',
#   'for',
#   'coffee',
#   'he',
#   'came',
#   'out',
#   'of',
#   'his',
#   'storage',
#   'room',
#   'with',
#   'a',
#   'packet',
#   'of',
#   'mccanns',
#   'instant',
#   'irish',
#   'oatmeal'],
#  ['he',
#   'suggested',
#   'that',
#   'i',
#   'try',
#   'it',
#   'for',
#   'my',
#   'own',
#   'use',
#   'in',
#   'my',
#   'stash'],
#  ['sometimes',
#   'nate',
#   'dose',
#   'not',
#   'give',
#   'you',
#   'a',
#   'chance',
#   'to',
#   'say',
#   'no',
#   'so',
#   'i',
#   'ended',
#   'up',
#   'trying',
#   'the',
#   'apple',
#   'and',
#   'cinn'],
#  ['found',
#   'it',
#   'to',
#   'be',
#   'very',
#   'tastefull',
#   'when',
#   'made',
#   'with',
#   'water',
#   'or',
#   'powdered',
#   'milk'],
#  ['it', 'goes', 'good', 'with'],
#  ['and',
#   'coffee',
#   'and',
#   'a',
#   'slice',
#   'of',
#   'toast',
#   'and',
#   'your',
#   'ready',
#   'to',
#   'take',
#   'on',
#   'the',
#   'world',
#   'or',
#   'the',
#   'day',
#   'at',
#   'least',
#   'jerry',
#   'reith'],
#  ['i',
#   'ordered',
#   'this',
#   'for',
#   'my',
#   'wife',
#   'a',
#   'it',
#   'wa',
#   'reccomended',
#   'by',
#   'our',
#   'daughter'],
#  ['she',
#   'ha',
#   'this',
#   'almost',
#   'every',
#   'morning',
#   'and',
#   'like',
#   'all',
#   'flavor'],
#  ['she', 'happy', 'i', 'happy'],
#  ['br',
#   'a',
#   'http',
#   'mccann',
#   'instant',
#   'irish',
#   'oatmeal',
#   'variety',
#   'pack',
#   'of',
#   'regular',
#   'apples',
#   'cinnamon',
#   'and',
#   'maple',
#   'brown',
#   'sugar',
#   'boxes',
#   'pack',
#   'of',
#   '6',
#   'the',
#   'variety',
#   'pack',
#   'taste',
#   'great',
#   'br',
#   'br',
#   'i',
#   'have',
#   'them',
#   'every',
#   'morning'],
#  ['at',
#   'cent',
#   'per',
#   'meal',
#   'i',
#   'do',
#   'understand',
#   'why',
#   'everyone',
#   'on',
#   'earth',
#   'is',
#   'buying',
#   'this',
#   'stuff',
#   'br',
#   'br',
#   'maple',
#   'and',
#   'brown',
#   'sugar',
#   'is',
#   'terrific',
#   'followed',
#   'by',
#   'apple',
#   'and',
#   'cinnamon',
#   'followed',
#   'by',
#   'regular'],
#  ['you',
#   'do',
#   'get',
#   'tired',
#   'of',
#   'the',
#   'same',
#   'ole',
#   'thing',
#   'and',
#   'they',
#   'taste',
#   'br',
#   'br',
#   'i',
#   'just',
#   'boil',
#   'water',
#   'from',
#   'a',
#   'small',
#   'pot',
#   'empty',
#   'the',
#   'packet',
#   'or',
#   '2',
#   'in',
#   'a',
#   'bowl',
#   'pour',
#   'in',
#   'boiling',
#   'water',
#   'and',
#   'watch',
#   'it',
#   'expand',
#   'to',
#   '2x',
#   'it',
#   'size',
#   'br',
#   'br',
#   'taste',
#   'really',
#   'good',
#   'and',
#   'take',
#   'minute',
#   'to',
#   'br',
#   'br',
#   'not',
#   'sure',
#   'why',
#   'everyone',
#   'on',
#   'earth',
#   'is',
#   'this'],
#  ['convenient',
#   'healthy',
#   'very',
#   'quick',
#   'excellent',
#   'quality',
#   'and',
#   'extremely',
#   'cheap',
#   'mccann',
#   'make',
#   'oatmeal',
#   'for',
#   'every',
#   'oatmeal',
#   'connoisseur',
#   'whether',
#   'one',
#   'like',
#   'it',
#   'from',
#   'the',
#   'raw',
#   'pellet',
#   'state',
#   'that',
#   'cook',
#   'for',
#   'half',
#   'an',
#   'hour',
#   'to',
#   'the',
#   'sloth',
#   'addled',
#   'instant',
#   'which',
#   'can',
#   'be',
#   'done',
#   'in',
#   'the',
#   'microwave',
#   'for',
#   'under',
#   'three',
#   'minute'],
#  ['it',
#   'all',
#   'good',
#   'that',
#   'for',
#   'sure',
#   'and',
#   'the',
#   'beauty',
#   'of',
#   'the',
#   'instant',
#   'variety',
#   'is',
#   'that',
#   'it',
#   'is',
#   'available',
#   'in',
#   'different',
#   'flavor',
#   'a',
#   'well',
#   'a',
#   'br',
#   'this',
#   'variety',
#   'pack',
#   'allows',
#   'different',
#   'taste',
#   'to',
#   'be',
#   'explored',
#   'a',
#   'well',
#   'a',
#   'giving',
#   'you',
#   'a',
#   'chance',
#   'to',
#   'experience',
#   'the',
#   'difference',
#   'between',
#   'mccann',
#   'and',
#   'other',
#   'oatmeal'],
#  ['what',
#   'i',
#   'personally',
#   'like',
#   'about',
#   'mccann',
#   'is',
#   'that',
#   'it',
#   'cook',
#   'up',
#   'thicker',
#   'and',
#   'with',
#   'more',
#   'body',
#   'than',
#   'the',
#   'top',
#   'brand',
#   'here',
#   'in',
#   'america'],
#  ['the',
#   'apples',
#   'cinnamon',
#   'though',
#   'tends',
#   'to',
#   'be',
#   'a',
#   'little',
#   'liquidy',
#   'so',
#   'you',
#   'may',
#   'want',
#   'to',
#   'experiment',
#   'with',
#   'the',
#   'amount',
#   'of',
#   'water',
#   'you',
#   'add'],
#  ['in',
#   'my',
#   '1300watt',
#   'microwave',
#   'the',
#   'oatmeal',
#   'cook',
#   'up',
#   'in',
#   'about',
#   'one',
#   'minute',
#   'and',
#   'second',
#   'so',
#   'you',
#   'should',
#   'also',
#   'watch',
#   'that',
#   'to',
#   'get',
#   'a',
#   'handle',
#   'on',
#   'how',
#   'much',
#   'time',
#   'and',
#   'water',
#   'to',
#   'br',
#   'the',
#   'only',
#   'bad',
#   'thing',
#   'if',
#   'you',
#   'can',
#   'consider',
#   'it',
#   'a',
#   'bad',
#   'thing',
#   'about',
#   'this',
#   'offering',
#   'is',
#   'that',
#   'you',
#   'have',
#   'to',
#   'buy',
#   'in',
#   'lot',
#   'so',
#   'you',
#   'end',
#   'up',
#   'with',
#   'six',
#   'box'],
#  ['this',
#   'is',
#   'good',
#   'if',
#   'you',
#   'have',
#   'a',
#   'whole',
#   'family',
#   'of',
#   'but',
#   'if',
#   'you',
#   'a',
#   'single',
#   'person',
#   'alone',
#   'well',
#   'love',
#   'oatmeal'],
#  ['i',
#   'have',
#   'mccann',
#   'oatmeal',
#   'every',
#   'morning',
#   'and',
#   'by',
#   'ordering',
#   'it',
#   'from',
#   'amazon',
#   'i',
#   'am',
#   'able',
#   'to',
#   'save',
#   'almost',
#   'per',
#   'br',
#   'it',
#   'is',
#   'a',
#   'great',
#   'product'],
#  ['tastes',
#   'great',
#   'and',
#   'very',
#   'healthy',
#   'mccann',
#   'oatmeal',
#   'is',
#   'a',
#   'good',
#   'quality',
#   'choice'],
#  ['our',
#   'favorite',
#   'is',
#   'the',
#   'apples',
#   'and',
#   'cinnamon',
#   'but',
#   'we',
#   'find',
#   'that',
#   'none',
#   'of',
#   'these',
#   'are',
#   'overly',
#   'sugary'],
#  ['for',
#   'a',
#   'good',
#   'hot',
#   'breakfast',
#   'in',
#   '2',
#   'minute',
#   'this',
#   'is',
#   'excellent'],
#  ['we',
#   'really',
#   'like',
#   'the',
#   'mccann',
#   'steel',
#   'cut',
#   'oat',
#   'but',
#   'find',
#   'we',
#   'do',
#   'cook',
#   'it',
#   'up',
#   'too',
#   'br',
#   'this',
#   'taste',
#   'much',
#   'better',
#   'to',
#   'me',
#   'than',
#   'the',
#   'grocery',
#   'store',
#   'brand',
#   'and',
#   'is',
#   'just',
#   'a',
#   'br',
#   'anything',
#   'that',
#   'keep',
#   'me',
#   'eating',
#   'oatmeal',
#   'regularly',
#   'is',
#   'a',
#   'good',
#   'thing'],
#  ['this',
#   'seems',
#   'a',
#   'little',
#   'more',
#   'wholesome',
#   'than',
#   'some',
#   'of',
#   'the',
#   'supermarket',
#   'brand',
#   'but',
#   'it',
#   'is',
#   'somewhat',
#   'mushy',
#   'and',
#   'doe',
#   'have',
#   'quite',
#   'a',
#   'much',
#   'flavor',
#   'either'],
#  ['it',
#   'did',
#   'pas',
#   'muster',
#   'with',
#   'my',
#   'kid',
#   'so',
#   'i',
#   'probably',
#   'wo',
#   'buy',
#   'it',
#   'again'],
#  ['good', 'oatmeal'],
#  ['i', 'like', 'the', 'apple', 'cinnamon', 'the', 'best'],
#  ['though',
#   'i',
#   'would',
#   'follow',
#   'the',
#   'direction',
#   'on',
#   'the',
#   'package',
#   'since',
#   'it',
#   'always',
#   'come',
#   'out',
#   'too',
#   'soupy',
#   'for',
#   'my',
#   'taste'],
#  ['that',
#   'could',
#   'just',
#   'be',
#   'me',
#   'since',
#   'i',
#   'like',
#   'my',
#   'oatmeal',
#   'really',
#   'thick',
#   'to',
#   'add',
#   'some',
#   'milk',
#   'on',
#   'top',
#   'of'],
#  ['the', 'flavor', 'are', 'good'],
#  ['however',
#   'i',
#   'do',
#   'not',
#   'see',
#   'any',
#   'differce',
#   'between',
#   'this',
#   'and',
#   'oaker',
#   'oats',
#   'brand',
#   'they',
#   'are',
#   'both',
#   'mushy'],
#  ['i', 'really', 'like', 'the', 'maple', 'and', 'brown', 'sugar', 'flavor'],
#  ['the', 'regular', 'is', 'fine', 'with', 'brown', 'sugar', 'added'],
#  ['the', 'apples', 'and', 'cinnamon', 'flavor', 'is', 'ok'],
#  ['this',
#   'is',
#   'a',
#   'very',
#   'quick',
#   'easy',
#   'and',
#   'satisfying',
#   'breakfast',
#   'and',
#   'i',
#   'order',
#   'this',
#   'brand',
#   'again',
#   'but',
#   'not',
#   'the',
#   'variety'],
#  ['i', 'get', 'all', 'maple', 'and', 'brown', 'sugar'],
#  ['this',
#   'is',
#   'the',
#   'same',
#   'stuff',
#   'you',
#   'can',
#   'buy',
#   'at',
#   'the',
#   'big',
#   'box',
#   'store'],
#  ['there', 'is', 'nothing', 'healthy', 'about', 'it'],
#  ['it', 'is', 'just', 'carbs', 'and', 'sugar'],
#  ['save',
#   'your',
#   'money',
#   'and',
#   'get',
#   'something',
#   'that',
#   'at',
#   'least',
#   'ha',
#   'some',
#   'taste'],
#  ['this', 'oatmeal', 'is', 'not', 'good'],
#  ['its', 'mushy', 'soft', 'i', 'do', 'like', 'it'],
#  ['quaker', 'oats', 'is', 'the', 'way', 'to', 'go'],
#  ['got',
#   'a',
#   'free',
#   'package',
#   'of',
#   'these',
#   'with',
#   'a',
#   'bottle',
#   'of',
#   'bloody',
#   'mary',
#   'mix',
#   'i',
#   'bought',
#   'from',
#   'the',
#   'seller',
#   'and',
#   'the',
#   'advertising',
#   'worked',
#   'lol',
#   'i',
#   'tried',
#   'them',
#   'and',
#   'shared',
#   'them',
#   'with',
#   '2',
#   'buddy',
#   'and',
#   'we',
#   'all',
#   'loved',
#   'them'],
#  ['so',
#   'im',
#   'here',
#   'to',
#   'buy',
#   'more',
#   'and',
#   'noticed',
#   'there',
#   'were',
#   'no',
#   'review',
#   'yet',
#   'well',
#   'now',
#   'there',
#   'is'],
#  ['they',
#   'are',
#   'hot',
#   'but',
#   'not',
#   'burn',
#   'your',
#   'mouth',
#   'forever',
#   'hot',
#   'it',
#   'a',
#   'nice',
#   'temp'],
#  ['perfect', 'for', 'u'],
#  ['this', 'wa', 'in', 'stock', 'the', 'last', 'time', 'i', 'looked'],
#  ['i',
#   'had',
#   'to',
#   'go',
#   'to',
#   'the',
#   'vermont',
#   'country',
#   'store',
#   'in',
#   'weston',
#   'to',
#   'find',
#   'it',
#   'along',
#   'with',
#   'a',
#   'jaw',
#   'harp',
#   'cranberry',
#   'horseradish',
#   'sauce',
#   'fartless',
#   'black',
#   'bean',
#   'salsa',
#   'apple',
#   'cider',
#   'jelly',
#   'newton',
#   'cradle',
#   'art',
#   'in',
#   'motion',
#   'and',
#   'the',
#   'staple',
#   'vermont',
#   'maple',
#   'br',
#   'br',
#   'back',
#   'to',
#   'the',
#   'ass',
#   'kickin',
#   'peanuts'],
#  ['they', 'are', 'hot'],
#  ['they',
#   'will',
#   'activate',
#   'the',
#   'perspiration',
#   'gland',
#   'behind',
#   'your',
#   'ear',
#   'and',
#   'under',
#   'your',
#   'arm'],
#  ['it',
#   'requires',
#   'a',
#   'beverage',
#   'a',
#   'advertised',
#   'a',
#   'glass',
#   'of',
#   'very',
#   'cold',
#   'milk',
#   'and',
#   'a',
#   'box',
#   'of',
#   'kleenex',
#   'since',
#   'it',
#   'will',
#   'make',
#   'your',
#   'nose',
#   'run'],
#  ['they',
#   'look',
#   'like',
#   'ordinary',
#   'peanut',
#   'which',
#   'is',
#   'already',
#   'giving',
#   'me',
#   'idea',
#   'for',
#   'work'],
#  ['i',
#   'suspect',
#   'that',
#   'some',
#   'people',
#   'have',
#   'been',
#   'hitting',
#   'my',
#   'goody',
#   'in',
#   'my',
#   'absence',
#   'especially',
#   'my',
#   'colleague',
#   'greg'],
#  ['i',
#   'going',
#   'to',
#   'take',
#   'this',
#   'to',
#   'work',
#   'at',
#   'earliest',
#   'opportunity',
#   'and',
#   'empty',
#   'the',
#   'content',
#   'of',
#   'this',
#   'can',
#   'into',
#   'an',
#   'ordinary',
#   'planters',
#   'peanuts',
#   'can',
#   'and',
#   'then',
#   'see',
#   'whose',
#   'cry',
#   'or',
#   'whose',
#   'nose',
#   'is',
#   'running',
#   'when',
#   'i',
#   'br',
#   'br',
#   'the',
#   'can',
#   'should',
#   'be',
#   'shaken',
#   'to',
#   'ensure',
#   'the',
#   'spice',
#   'are',
#   'evenly',
#   'distributed'],
#  ['it',
#   'is',
#   'important',
#   'to',
#   'wash',
#   'your',
#   'hand',
#   'after',
#   'consumption',
#   'and',
#   'not',
#   'touch',
#   'the',
#   'br',
#   'br',
#   'you',
#   'go',
#   'nut',
#   'over',
#   'these',
#   'br',
#   'br'],
#  ['i',
#   'not',
#   'sharing',
#   'the',
#   'peanut',
#   'not',
#   'deliberately',
#   'and',
#   'i',
#   'probably',
#   'give',
#   'greg',
#   'the',
#   'jaw',
#   'harp',
#   'for',
#   'christmas'],
#  ['he', 'be', 'so', 'insulted'],
#  ['we',
#   'used',
#   'to',
#   'spicy',
#   'food',
#   'down',
#   'here',
#   'in',
#   'south',
#   'texas',
#   'and',
#   'these',
#   'are',
#   'not',
#   'at',
#   'all',
#   'spicy'],
#  ['doubt', 'very', 'much', 'habanero', 'is', 'used', 'at', 'all'],
#  ['could', 'take', 'it', 'up', 'a', 'notch', 'or', 'two'],
#  ['i',
#   'roast',
#   'at',
#   'home',
#   'with',
#   'a',
#   'popcorn',
#   'popper',
#   'but',
#   'i',
#   'do',
#   'it',
#   'outside',
#   'of',
#   'course'],
#  ['these',
#   'bean',
#   'coffee',
#   'bean',
#   'direct',
#   'green',
#   'mexican',
#   'altura',
#   'seem',
#   'to',
#   'be',
#   'for',
#   'this',
#   'method'],
#  ['the',
#   'first',
#   'and',
#   'second',
#   'crack',
#   'are',
#   'distinct',
#   'and',
#   'i',
#   'roasted',
#   'the',
#   'bean',
#   'from',
#   'medium',
#   'to',
#   'slightly',
#   'dark',
#   'with',
#   'great',
#   'result',
#   'every',
#   'time'],
#  ['the', 'aroma', 'is', 'strong', 'and', 'persistent'],
#  ['the', 'taste', 'is', 'smooth', 'velvety', 'yet', 'lively'],
#  ['we',
#   'roast',
#   'these',
#   'in',
#   'a',
#   'large',
#   'cast',
#   'iron',
#   'pan',
#   'on',
#   'the',
#   'grill',
#   'about',
#   'of',
#   'the',
#   'bag',
#   'at',
#   'a',
#   'time'],
#  ['the',
#   'smell',
#   'is',
#   'wonderful',
#   'and',
#   'the',
#   'roasted',
#   'bean',
#   'taste',
#   'delicious',
#   'too'],
#  ['more',
#   'importantly',
#   'the',
#   'coffee',
#   'is',
#   'smooth',
#   'no',
#   'bitter',
#   'aftertaste'],
#  ['on',
#   'numerous',
#   'occasion',
#   'we',
#   'had',
#   'to',
#   'send',
#   'the',
#   'roasted',
#   'bean',
#   'home',
#   'with',
#   'friend',
#   'because',
#   'they',
#   'like',
#   'it',
#   'so',
#   'much'],
#  ['deal', 'wa', 'awesome'],
#  ['arrived',
#   'before',
#   'halloween',
#   'a',
#   'indicated',
#   'and',
#   'wa',
#   'enough',
#   'to',
#   'satisfy',
#   'trick',
#   'or',
#   'treater'],
#  ['i',
#   'love',
#   'the',
#   'quality',
#   'of',
#   'this',
#   'product',
#   'and',
#   'it',
#   'wa',
#   'much',
#   'le',
#   'expensive',
#   'than',
#   'the',
#   'local',
#   'store',
#   'candy'],
#  ['it', 'is', 'chocolate', 'what', 'can', 'i', 'say'],
#  ['great', 'variety', 'of', 'everything', 'our', 'family', 'love'],
#  ['with', 'a', 'family', 'of', 'six', 'it', 'go', 'fast', 'here'],
#  ['perfect', 'variety'],
#  ['kit', 'kat', 'reeses', 'take', 'five', 'and', 'more'],
#  ['great',
#   'product',
#   'nice',
#   'combination',
#   'of',
#   'chocolate',
#   'and',
#   'perfect',
#   'size'],
#  ['the', 'bag', 'had', 'plenty', 'and', 'they', 'were', 'shipped', 'promptly'],
#  ['the', 'kid', 'in', 'the', 'neighborhood', 'liked', 'our', 'candy'],
#  ['halloween',
#   'is',
#   'over',
#   'but',
#   'i',
#   'sent',
#   'a',
#   'bag',
#   'to',
#   'my',
#   'daughter',
#   'class',
#   'for',
#   'her',
#   'share'],
#  ['the', 'chocolate', 'wa', 'fresh', 'and', 'enjoyed', 'by', 'many'],
#  ['watch', 'your', 'price', 'with', 'this'],
#  ['while',
#   'the',
#   'assortment',
#   'wa',
#   'good',
#   'and',
#   'i',
#   'did',
#   'get',
#   'this',
#   'on',
#   'a',
#   'gold',
#   'box',
#   'purchase',
#   'the',
#   'price',
#   'for',
#   'this',
#   'wa',
#   'br',
#   'le',
#   'at',
#   'target'],
#  ['this',
#   'bag',
#   'of',
#   'candy',
#   'online',
#   'is',
#   'pretty',
#   'expensive',
#   'it',
#   'should',
#   'be',
#   'cheaper',
#   'in',
#   'order',
#   'to',
#   'compete',
#   'with',
#   'grocery',
#   'store',
#   'other',
#   'than',
#   'that',
#   'it',
#   'a',
#   'good',
#   'combination',
#   'of',
#   'my',
#   'favorite',
#   'candy',
#   'arrived',
#   'in',
#   '6',
#   'day',
#   'and',
#   'were',
#   'so',
#   'stale',
#   'i',
#   'could',
#   'not',
#   'eat',
#   'any',
#   'of',
#   'the',
#   '6',
#   'bag'],
#  ['i',
#   'have',
#   'used',
#   'the',
#   'endurolyte',
#   'product',
#   'for',
#   'several',
#   'year',
#   'in',
#   'both',
#   'pill',
#   'and',
#   'powder',
#   'form'],
#  ['long',
#   'desert',
#   'ride',
#   'on',
#   'the',
#   'dirt',
#   'bike',
#   'always',
#   'found',
#   'my',
#   'camelbak',
#   'water',
#   'heavily',
#   'laced',
#   'with',
#   'the',
#   'endurolyte',
#   'powder',
#   'not',
#   'overly',
#   'tasty',
#   'but',
#   'quite',
#   'effective',
#   'a',
#   'i',
#   'never',
#   'got',
#   'a',
#   'cramp',
#   'on',
#   'these',
#   'several',
#   'hundred',
#   'mile',
#   'ride'],
#  ['same',
#   'for',
#   'desert',
#   'racing',
#   'in',
#   'the',
#   'buggy',
#   'the',
#   'camelbaks',
#   'were',
#   'always',
#   'laced',
#   'with',
#   'the',
#   'powder'],
#  ['now', 'we', 'have', 'the', 'fizz', 'what', 'a', 'great', 'product'],
#  ['firstly',
#   'it',
#   'hammer',
#   'endurolyte',
#   'product',
#   'so',
#   'it',
#   'great',
#   'endurance',
#   'athlete',
#   'the',
#   'world',
#   'over',
#   'use',
#   'their',
#   'product'],
#  ['second',
#   'it',
#   'convenient',
#   'handly',
#   'tablet',
#   'that',
#   'dissovle',
#   'in',
#   'a',
#   'fizz'],
#  ['third', 'it', 'taste', 'great'],
#  ['imagine',
#   'getting',
#   'a',
#   'nice',
#   'cool',
#   'drink',
#   'when',
#   'your',
#   'body',
#   'is',
#   'starving',
#   'for',
#   'hydration',
#   'and',
#   'electrolyte',
#   'and',
#   'rather',
#   'than',
#   'getting',
#   'a',
#   'salty',
#   'taste',
#   'you',
#   'get',
#   'a',
#   'refreshing',
#   'or',
#   'mango'],
#  ['the', 'camelbaks', 'always', 'get', 'the', 'fizz', 'now'],
#  ['i',
#   'also',
#   'drop',
#   'a',
#   'tablet',
#   'in',
#   'my',
#   'bottled',
#   'water',
#   'whenever',
#   'i',
#   'exercise',
#   'and',
#   'have',
#   'a',
#   'nice',
#   'flavored',
#   'water',
#   'chock',
#   'full',
#   'of',
#   'electrolyte'],
#  ['i',
#   'can',
#   'not',
#   'recommend',
#   'this',
#   'product',
#   'or',
#   'any',
#   'hammer',
#   'product',
#   'highly',
#   'enough'],
#  ['this',
#   'product',
#   'serf',
#   'me',
#   'well',
#   'a',
#   'a',
#   'source',
#   'of',
#   'electrolyte',
#   'during',
#   'and',
#   'after',
#   'a',
#   'long',
#   'run',
#   'or',
#   'bike',
#   'br',
#   'i',
#   'have',
#   'tried',
#   'all',
#   'of',
#   'the',
#   'flavor',
#   'but',
#   'really',
#   'do',
#   'like',
#   'the',
#   'grapefruit',
#   'flavor',
#   'no',
#   'and',
#   'i',
#   'actually',
#   'like',
#   'the',
#   'slight',
#   'br',
#   'i',
#   'use',
#   'other',
#   'hammer',
#   'product',
#   'and',
#   'really',
#   'like',
#   'their',
#   'whole',
#   'product',
#   'line'],
#  ['this',
#   'stuff',
#   'really',
#   'work',
#   'for',
#   'preventing',
#   'cramping',
#   'during',
#   'the',
#   'middle',
#   'to',
#   'latter',
#   'stage',
#   'of',
#   'your',
#   'ride'],
#  ['pop', '1', 'into', 'each', 'water', 'bottle', 'and', 'you', 'set'],
#  ['flavor', 'is', 'fine', 'and', 'go', 'down', 'easy'],
#  ['for',
#   'those',
#   'of',
#   'u',
#   'on',
#   'a',
#   'low',
#   'carb',
#   'diet',
#   'these',
#   'little',
#   'tablet',
#   'are',
#   'just',
#   'the',
#   'br',
#   'br',
#   'two',
#   'year',
#   'ago',
#   'i',
#   'started',
#   'cycling',
#   'again',
#   'after',
#   'many',
#   'year',
#   'but',
#   'wa',
#   'having',
#   'heart',
#   'arrhythmia',
#   'after',
#   'longer',
#   'ride',
#   'in',
#   'high',
#   'heat'],
#  ['i',
#   'wa',
#   'drinking',
#   'plain',
#   'water',
#   'but',
#   'did',
#   'a',
#   'little',
#   'research',
#   'and',
#   'thought',
#   'electrolyte',
#   'might',
#   'be',
#   'the',
#   'issue'],
#  ['gatorade',
#   'wa',
#   'an',
#   'option',
#   'because',
#   'it',
#   'is',
#   'so',
#   'loaded',
#   'with',
#   'carbohydrate',
#   'so',
#   'i',
#   'looked',
#   'around',
#   'for',
#   'a',
#   'alternative'],
#  ['the',
#   'zero',
#   'carb',
#   'sport',
#   'drink',
#   'did',
#   'help',
#   'so',
#   'what',
#   'to',
#   'do'],
#  ['one',
#   'day',
#   'i',
#   'ran',
#   'across',
#   'these',
#   'at',
#   'my',
#   'bike',
#   'shop',
#   'so',
#   'tried',
#   'a',
#   'tube',
#   'of',
#   'them',
#   'voila',
#   'problem',
#   'solved'],
#  ['br',
#   'br',
#   'i',
#   'shared',
#   'them',
#   'with',
#   'two',
#   'friend',
#   'in',
#   'particular',
#   'whose',
#   'problem',
#   'with',
#   'leg',
#   'cramp',
#   'were',
#   'resolved',
#   'while',
#   'using',
#   'br',
#   'br',
#   'these',
#   'guy',
#   'got',
#   'it',
#   'right',
#   'they',
#   'are',
#   'superbly',
#   'formulated',
#   'and',
#   'simply',
#   'work'],
#  ['i',
#   'purchased',
#   'the',
#   'mango',
#   'flavor',
#   'and',
#   'to',
#   'me',
#   'it',
#   'doe',
#   'take',
#   'like',
#   'mango',
#   'at',
#   'all'],
#  ['there',
#   'is',
#   'no',
#   'hint',
#   'of',
#   'sweetness',
#   'and',
#   'unfortunately',
#   'there',
#   'is',
#   'a',
#   'hint',
#   'or',
#   'aftertaste',
#   'almost',
#   'like',
#   'licorice'],
#  ['i',
#   'been',
#   'consuming',
#   'various',
#   'sport',
#   'nutrition',
#   'product',
#   'for',
#   'decade',
#   'so',
#   'i',
#   'familiar',
#   'and',
#   'have',
#   'come',
#   'to',
#   'like',
#   'the',
#   'taste',
#   'of',
#   'the',
#   'most',
#   'of',
#   'the',
#   'product',
#   'i',
#   'tried'],
#  ['the',
#   'mango',
#   'flavor',
#   'is',
#   'one',
#   'of',
#   'the',
#   'least',
#   'appealing',
#   'i',
#   'tasted'],
#  ['it',
#   'not',
#   'terrible',
#   'but',
#   'it',
#   'bad',
#   'enough',
#   'that',
#   'i',
#   'notice',
#   'the',
#   'bad',
#   'taste',
#   'every',
#   'sip',
#   'i',
#   'take'],
#  ['if',
#   'you',
#   'impulsive',
#   'like',
#   'me',
#   'then',
#   '6',
#   'is',
#   'do',
#   'get',
#   'me',
#   'wrong',
#   'the',
#   'quality',
#   'of',
#   'these',
#   'baby',
#   'is',
#   'very',
#   'good',
#   'and',
#   'i',
#   'have',
#   'no',
#   'complaint'],
#  ['but',
#   'in',
#   'retrospect',
#   'the',
#   'price',
#   'is',
#   'a',
#   'little',
#   'ridiculous',
#   'esp'],
#  ['when', 'you', 'add', 'on', 'the', 'shipping'],
#  ['this',
#   'wa',
#   'sooooo',
#   'deliscious',
#   'but',
#   'too',
#   'bad',
#   'i',
#   'ate',
#   'em',
#   'too',
#   'fast',
#   'and',
#   'gained',
#   '2',
#   'pd'],
#  ['my',
#   'fault',
#   'these',
#   'albanese',
#   'gummi',
#   'bear',
#   'and',
#   'ring',
#   'and',
#   'so',
#   'on',
#   'are',
#   'very',
#   'good',
#   'and',
#   'tasty',
#   'and',
#   'high',
#   'quality'],
#  ['the', 'bear', 'even', 'have', 'little', 'face'],
#  ['at',
#   'my',
#   'local',
#   'candy',
#   'store',
#   'this',
#   'type',
#   'of',
#   'gummi',
#   'stuff',
#   'bear',
#   'ring',
#   'snake',
#   'ball',
#   'worm',
#   'whatever',
#   'are',
#   'about'],
#  ['these',
#   'twin',
#   'pack',
#   'of',
#   'or',
#   '5',
#   'pound',
#   'bag',
#   'is',
#   'a',
#   'screaming',
#   'deal',
#   'a',
#   'far',
#   'a',
#   'i',
#   'concerned'],
#  ['i', 'probably', '50', 'pound', 'deep', 'in', 'these', 'friggin', 'thing'],
#  ['consumed'],
#  ['grape', 'gummy', 'bear', 'are', 'hard', 'to', 'find', 'in', 'my', 'area'],
#  ['in',
#   'fact',
#   'pretty',
#   'much',
#   'anyone',
#   'i',
#   'talk',
#   'to',
#   'about',
#   'grape',
#   'gummy',
#   'bear',
#   'they',
#   'think',
#   'i',
#   'lying'],
#  ['so',
#   'i',
#   'bought',
#   '10lbs',
#   'these',
#   'bear',
#   'are',
#   'a',
#   'little',
#   'bit',
#   'bigger',
#   'then',
#   'the',
#   'other',
#   'brand',
#   'and',
#   'have',
#   'kind',
#   'of',
#   'sour',
#   'kick',
#   'but',
#   'nothing',
#   'to',
#   'strong'],
#  ['i', 'love', 'grape', 'flavored', 'and', 'these', 'are', 'pretty', 'good'],
#  ['there',
#   'is',
#   'another',
#   'company',
#   'that',
#   'make',
#   'grape',
#   'gummy',
#   'bear',
#   'that',
#   'are',
#   'a',
#   'little',
#   'bit',
#   'better',
#   'in',
#   'my',
#   'opinion',
#   'but',
#   'these',
#   'are',
#   'well',
#   'worth',
#   'it',
#   'for',
#   'the',
#   'price'],
#  ['i',
#   'like',
#   'to',
#   'use',
#   'the',
#   'gummy',
#   'bear',
#   'in',
#   'home',
#   'made',
#   'popsicles',
#   'with',
#   'flavored',
#   'sport',
#   'drink'],
#  ['the',
#   'salt',
#   'in',
#   'the',
#   'sport',
#   'drink',
#   'make',
#   'for',
#   'softer',
#   'popsicle',
#   'and',
#   'the',
#   'gummy',
#   'bear',
#   'are',
#   'awesome',
#   'frozen'],
#  ['they', 'are', 'delicious'],
#  ['i',
#   'ordered',
#   'two',
#   'of',
#   'these',
#   'and',
#   'two',
#   'of',
#   'raspberry',
#   'latice',
#   'tart',
#   'directly',
#   'from',
#   'fantasicakes',
#   'website',
#   'for',
#   'a',
#   'dinner',
#   'party',
#   'i',
#   'wa',
#   'hosting'],
#  ['it', 'arrived', 'fresh', 'and', 'intact'],
#  ['very', 'good', 'size'],
#  ['i', 'froze', 'half', 'for', 'later', 'use'],
#  ['i',
#   'am',
#   'a',
#   'pastry',
#   'lover',
#   'and',
#   'these',
#   'were',
#   'the',
#   'best',
#   'i',
#   'ever',
#   'tasted'],
#  ['the',
#   'pastry',
#   'wa',
#   'soft',
#   'the',
#   'jam',
#   'wa',
#   'really',
#   'good',
#   'and',
#   'the',
#   'taste',
#   'wa',
#   'great'],
#  ['they', 'were', 'gone', 'in', 'no', 'time'],
#  ['my', 'guest', 'were', 'really', 'impressed'],
#  ['buyer', 'beware', 'please'],
#  ['this', 'sweetener', 'is', 'not', 'for', 'everybody'],
#  ['maltitol',
#   'is',
#   'an',
#   'alcohol',
#   'sugar',
#   'and',
#   'can',
#   'be',
#   'undigestible',
#   'in',
#   'the',
#   'body'],
#  ['you',
#   'will',
#   'know',
#   'a',
#   'short',
#   'time',
#   'after',
#   'consuming',
#   'it',
#   'if',
#   'you',
#   'are',
#   'one',
#   'of',
#   'the',
#   'unsuspecting',
#   'many',
#   'who',
#   'can',
#   'not',
#   'digest',
#   'it',
#   'by',
#   'the',
#   'extreme',
#   'intestinal',
#   'bloating',
#   'and',
#   'cramping',
#   'and',
#   'massive',
#   'amount',
#   'of',
#   'gas',
#   'a',
#   'person',
#   'can',
#   'experience'],
#  ['nausea', 'diarrhea', 'headache', 'can', 'also', 'be', 'experienced'],
#  ['i',
#   'learned',
#   'my',
#   'lesson',
#   'the',
#   'hard',
#   'way',
#   'year',
#   'ago',
#   'when',
#   'i',
#   'fell',
#   'in',
#   'love',
#   'with',
#   'the',
#   'chocolate',
#   'suzanne',
#   'sommers',
#   'used',
#   'to',
#   'sell'],
#  ['i',
#   'thought',
#   'i',
#   'found',
#   'chocolate',
#   'nirvana',
#   'at',
#   'first',
#   'taste',
#   'but',
#   'the',
#   'bliss',
#   'wa',
#   'short',
#   'lived',
#   'when',
#   'the',
#   'terrible',
#   'side',
#   'effect',
#   'of',
#   'maltitol',
#   'kicked',
#   'in'],
#  ['the',
#   'discomfort',
#   'wa',
#   'unlike',
#   'anything',
#   'i',
#   'had',
#   'ever',
#   'felt',
#   'before'],
#  ['i',
#   'blew',
#   'up',
#   'like',
#   'a',
#   'balloon',
#   'and',
#   'had',
#   'very',
#   'painful',
#   'abdominal',
#   'cramping'],
#  ['as', 'the', 'symptom', 'passed', 'this', 'too', 'wa', 'very', 'unpleasant'],
#  ['though',
#   'hard',
#   'for',
#   'me',
#   'to',
#   'believe',
#   'a',
#   'low',
#   'calorie',
#   'sweetener',
#   'could',
#   'be',
#   'the',
#   'culprit',
#   'all',
#   'symptom',
#   'were',
#   'gone',
#   'when',
#   'i',
#   'stopped',
#   'eating',
#   'the',
#   'chocolate'],
#  ['my',
#   'hunch',
#   'it',
#   'had',
#   'something',
#   'to',
#   'do',
#   'with',
#   'the',
#   'maltitol',
#   'were',
#   'unfortunately',
#   'confirmed',
#   'for',
#   'me',
#   'about',
#   'a',
#   'year',
#   'later',
#   'when',
#   'i',
#   'purchased',
#   'some',
#   'delicious',
#   'popcorn',
#   'at',
#   'my',
#   'local',
#   'market'],
#  ['the',
#   'taste',
#   'wa',
#   'amazing',
#   'and',
#   'while',
#   'i',
#   'wa',
#   'looking',
#   'at',
#   'the',
#   'label',
#   'wondering',
#   'what',
#   'could',
#   'possibly',
#   'make',
#   'this',
#   'yummy',
#   'new',
#   'sugarfree',
#   'treat',
#   'taste',
#   'so',
#   'good',
#   'my',
#   'heart',
#   'sank',
#   'when',
#   'i',
#   'followed',
#   'the',
#   'little',
#   'asterisk',
#   'next',
#   'to',
#   'sugarfree',
#   'sweetener',
#   'down',
#   'to',
#   'the',
#   'very',
#   'bottom',
#   'of',
#   'the',
#   'label',
#   'and',
#   'read',
#   'maltitol',
#   'in',
#   'tiny',
#   'little',
#   'letter'],
#  ['thank', 'goodness', 'i', 'eaten', 'only', 'a', 'little'],
#  ['i',
#   'still',
#   'ended',
#   'up',
#   'with',
#   'all',
#   'the',
#   'same',
#   'but',
#   'for',
#   'a',
#   'much',
#   'shorter',
#   'duration'],
#  ['some',
#   'people',
#   'can',
#   'use',
#   'maltitol',
#   'to',
#   'their',
#   'heart',
#   'content',
#   'but',
#   'others',
#   'like',
#   'me',
#   'can',
#   'have',
#   'a',
#   'bad',
#   'reaction',
#   'to',
#   'it'],
#  ['in',
#   'case',
#   'you',
#   'like',
#   'me',
#   'it',
#   'not',
#   'you',
#   'it',
#   'the',
#   'maltitol'],
#  ['it', 'is', 'okay'],
#  ['i',
#   'would',
#   'not',
#   'go',
#   'out',
#   'of',
#   'my',
#   'way',
#   'to',
#   'buy',
#   'it',
#   'again',
#   'no',
#   'tea',
#   'flavor',
#   'at',
#   'all'],
#  ['just', 'whole', 'brunch', 'of', 'artifial', 'flavor'],
#  ['it', 'is', 'not', 'returnable'],
#  ['i', 'wasted', 'buck'],
#  ['these',
#   'looked',
#   'like',
#   'a',
#   'perfect',
#   'snack',
#   'to',
#   'through',
#   'in',
#   'with',
#   'my',
#   'trail',
#   'mix'],
#  ['unfortunately',
#   'they',
#   'arrived',
#   'in',
#   'a',
#   'solid',
#   'mass',
#   'of',
#   'melted',
#   'chocolate'],
#  ['i',
#   'left',
#   'them',
#   'in',
#   'my',
#   'pantry',
#   'for',
#   'a',
#   'few',
#   'day',
#   'and',
#   'when',
#   'i',
#   'opened',
#   'them',
#   'at',
#   'room',
#   'temperature',
#   'they',
#   'were',
#   'still',
#   'gooey'],
#  ['i',
#   'through',
#   'them',
#   'in',
#   'the',
#   'fridge',
#   'and',
#   'i',
#   'been',
#   'breaking',
#   'off',
#   'hunk',
#   'ever',
#   'since'],
#  ['they',
#   'taste',
#   'good',
#   'to',
#   'me',
#   'but',
#   'the',
#   'chocolate',
#   'is',
#   'all',
#   'grainy',
#   'after',
#   'melting',
#   'and',
#   'then',
#   'solidifying',
#   'again'],
#  ['i',
#   'wo',
#   'order',
#   'them',
#   'online',
#   'again',
#   'but',
#   'if',
#   'i',
#   'see',
#   'them',
#   'in',
#   'a',
#   'store',
#   'i',
#   'would',
#   'pick',
#   'them',
#   'up'],
# ...
#   'these',
#   'problem',
#   'to',
#   'go',
#   'to',
#   'the',
#   'consumer',
#   'affair',
#   'website',
#   'and',
#   'also',
#   'the',
#   'fda',
#   'website',
#   'and',
#   'write',
#   'a',
#   'letter',
#   'to',
#   'them',
#   'to',
#   'let',
#   'them',
#   'know',
#   'how',
#   'this',
#   'ha',
#   'affected',
#   'your',
#   'animal'],
#  ['as',
#   'with',
#   'canidae',
#   'they',
#   'do',
#   'not',
#   'care',
#   'how',
#   'the',
#   'change',
#   'ha',
#   'affected',
#   'my',
#   'animal',
#   'and',
#   'tell',
#   'me',
#   'not',
#   'to',
#   'buy',
#   'it'],
#  ['this', 'is', 'just', 'horrible'],
#  ['do', 'buy', 'just', 'a', 'few', 'of', 'these'],
#  ['i', 'order', 'these', 'by', 'the', 'case'],
#  ['i',
#   'ca',
#   'even',
#   'remember',
#   'the',
#   'first',
#   'time',
#   'i',
#   'tasted',
#   'an',
#   'anchovy',
#   'stuffed',
#   'olive',
#   'but',
#   'i',
#   'have',
#   'tried',
#   'several',
#   'of',
#   'the',
#   'brand',
#   'online',
#   'and',
#   'this',
#   'brand',
#   'is',
#   'my',
#   'favorite'],
#  ['i', 'order', 'these', 'olive', 'a', 'lot'],
#  ['they', 'are', 'any', 'other', 'olive', 'out', 'there'],
#  ['the',
#   'subtle',
#   'flavor',
#   'of',
#   'the',
#   'brine',
#   'go',
#   'great',
#   'with',
#   'cheese'],
#  ['one', 'of', 'my', 'favorite', 'appetizer', 'treat', 'for', 'guest'],
#  ['hey',
#   'the',
#   'description',
#   'say',
#   '360',
#   'gram',
#   'that',
#   'is',
#   'roughly',
#   '13',
#   'ounce',
#   'at',
#   'under',
#   'per',
#   'can'],
#  ['no',
#   'way',
#   'that',
#   'is',
#   'the',
#   'approximate',
#   'price',
#   'for',
#   'a',
#   '100',
#   'gram',
#   'can'],
#  ['my',
#   'husband',
#   'and',
#   'i',
#   'are',
#   'both',
#   'kind',
#   'of',
#   'wimpy',
#   'when',
#   'it',
#   'come',
#   'to',
#   'hot',
#   'thing',
#   'and',
#   'this',
#   'seasoning',
#   'is',
#   'just',
#   'a',
#   'bit',
#   'too',
#   'spicy',
#   'for',
#   'u'],
#  ['it',
#   'definitely',
#   'make',
#   'you',
#   'sweat',
#   'a',
#   'bit',
#   'when',
#   'you',
#   'eating',
#   'it'],
#  ['it',
#   'wa',
#   'still',
#   'edible',
#   'to',
#   'u',
#   'by',
#   'adding',
#   'a',
#   'good',
#   'sized',
#   'dollop',
#   'of',
#   'sour',
#   'cream',
#   'but',
#   'i',
#   'do',
#   'think',
#   'i',
#   'would',
#   'buy',
#   'it',
#   'again',
#   'due',
#   'to',
#   'the',
#   'heat'],
#  ['we',
#   'prefer',
#   'the',
#   'milder',
#   'mccormick',
#   'brand',
#   'of',
#   'fajita',
#   'mix'],
#  ['i',
#   'also',
#   'had',
#   'fajitas',
#   'in',
#   'a',
#   'couple',
#   'of',
#   'different',
#   'restaurant',
#   'and',
#   'it',
#   'wa',
#   'a',
#   'spicy',
#   'a',
#   'this',
#   'mix',
#   'br',
#   'br',
#   'if',
#   'you',
#   'like',
#   'super',
#   'spicy',
#   'then',
#   'this',
#   'is',
#   'not',
#   'burning',
#   'hot',
#   'so',
#   'you',
#   'might',
#   'want',
#   'to',
#   'keep',
#   'that',
#   'in',
#   'mind'],
#  ['to',
#   'me',
#   'it',
#   'wa',
#   'more',
#   'than',
#   'medium',
#   'hot',
#   'but',
#   'not',
#   'by',
#   'too',
#   'br',
#   'br',
#   'i',
#   'gave',
#   'it',
#   'three',
#   'star',
#   'because',
#   'it',
#   'wa',
#   'pretty',
#   'easy',
#   'to',
#   'make',
#   'and',
#   'it',
#   'versatile',
#   'in',
#   'that',
#   'you',
#   'could',
#   'vary',
#   'the',
#   'veggie',
#   'you',
#   'put',
#   'in',
#   'it'],
#  ['you',
#   'take',
#   'a',
#   'plastic',
#   'bag',
#   'a',
#   'couple',
#   'of',
#   'tb',
#   'of',
#   'vegetable',
#   'oil',
#   'cup',
#   'water',
#   'and',
#   'mix',
#   'the',
#   'seasoning',
#   'water',
#   'and',
#   'oil',
#   'together',
#   'then',
#   'add',
#   'the',
#   'chicken',
#   'strip',
#   'to',
#   'the',
#   'bag',
#   'and',
#   'let',
#   'it',
#   'marinate',
#   'for',
#   '5',
#   'minute'],
#  ['in',
#   'the',
#   'meantime',
#   'it',
#   'say',
#   'to',
#   'stir',
#   'fry',
#   'your',
#   'veggie',
#   'pepper',
#   'and',
#   'onion',
#   'but',
#   'i',
#   'found',
#   'it',
#   'easier',
#   'to',
#   'just',
#   'cook',
#   'the',
#   'chicken',
#   'and',
#   'veggie',
#   'together',
#   'and',
#   'i',
#   'do',
#   'think',
#   'it',
#   'affected',
#   'quality',
#   'or',
#   'taste'],
#  ['i',
#   'also',
#   'used',
#   'extra',
#   'virgin',
#   'olive',
#   'oil',
#   'rather',
#   'than',
#   'vegetable',
#   'br',
#   'br',
#   'i',
#   'have',
#   'one',
#   'more',
#   'package',
#   'of',
#   'this',
#   'to',
#   'use',
#   'and',
#   'next',
#   'time',
#   'i',
#   'going',
#   'to',
#   'add',
#   'more',
#   'veggie',
#   'and',
#   'maybe',
#   'some',
#   'chopped',
#   'tomato',
#   'to',
#   'cut',
#   'the',
#   'heat',
#   'a',
#   'bit',
#   'more'],
#  ['a',
#   'friend',
#   'who',
#   'been',
#   'drinking',
#   'tea',
#   'for',
#   '80',
#   'of',
#   'his',
#   '84',
#   'year',
#   'introduced',
#   'me',
#   'to',
#   'this',
#   'tea',
#   'a',
#   'few',
#   'month',
#   'ago'],
#  ['even',
#   'took',
#   'me',
#   'over',
#   'to',
#   'the',
#   'store',
#   'and',
#   'bought',
#   'me',
#   'a',
#   'pound'],
#  ['at'],
#  ['in',
#   'a',
#   'retail',
#   'store',
#   'or',
#   'a',
#   'little',
#   'over',
#   '9',
#   'with',
#   'shipping',
#   'from',
#   'an',
#   'online',
#   'merchant',
#   'i',
#   'think',
#   'it',
#   'great'],
#  ['i',
#   'been',
#   'drinking',
#   'earl',
#   'grey',
#   'english',
#   'breakfast',
#   'irish',
#   'breakfast',
#   'lapsang',
#   'souchong',
#   'assam',
#   'etc'],
#  ['most', 'of', 'them', 'were', 'over'],
#  ['with', 'shipping'],
#  ['aside',
#   'from',
#   'the',
#   'lapsang',
#   'souchong',
#   'i',
#   'think',
#   'this',
#   'is',
#   'a',
#   'great',
#   'replacement',
#   'for',
#   'all',
#   'the',
#   'rest'],
#  ['has',
#   'everything',
#   'i',
#   'looking',
#   'for',
#   'in',
#   'a',
#   'strong',
#   'black',
#   'tea',
#   'with',
#   'enough',
#   'character',
#   'to',
#   'keep',
#   'it',
#   'from',
#   'becoming',
#   'boring'],
#  ['my', 'current', 'favorite', 'afternoon', 'tea'],
#  ['unless',
#   'you',
#   'extremely',
#   'jaded',
#   'or',
#   'a',
#   'tea',
#   'snob',
#   'you',
#   'love',
#   'it'],
#  ['i',
#   'love',
#   'strong',
#   'full',
#   'bodied',
#   'quality',
#   'tea',
#   'and',
#   'typically',
#   'drink',
#   'assam',
#   'irish',
#   'breakfast',
#   'or',
#   'early',
#   'grey',
#   'tea',
#   'but',
#   'a',
#   'the',
#   'other',
#   'reviewer',
#   'noted',
#   'the',
#   'price',
#   'per',
#   'pound',
#   'can',
#   'be',
#   'discouraging'],
#  ['so',
#   'i',
#   'have',
#   'been',
#   'searching',
#   'for',
#   'a',
#   'quality',
#   'full',
#   'bodied',
#   'tea',
#   'that',
#   'wa',
#   'bitter',
#   'at',
#   'a',
#   'more',
#   'palatable',
#   'price',
#   'point',
#   'and',
#   'this',
#   'certainly',
#   'fit',
#   'the',
#   'bill'],
#  ['and',
#   'unlike',
#   'some',
#   'other',
#   'tea',
#   'where',
#   'they',
#   'tend',
#   'to',
#   'be',
#   'better',
#   'in',
#   'one',
#   'form',
#   'or',
#   'another'],
#  ['iced', 'hot', 'this', 'tea', 'is', 'excellent', 'in', 'both', 'form'],
#  ['i',
#   'would',
#   'certainly',
#   'recommend',
#   'this',
#   'to',
#   'anyone',
#   'who',
#   'prefers',
#   'that',
#   'smooth',
#   'full',
#   'bodied',
#   'quality',
#   'tea',
#   'that',
#   'doe',
#   'cost',
#   'an',
#   'arm',
#   'and',
#   'leg'],
#  ['i',
#   'drink',
#   'this',
#   'tea',
#   'plain',
#   'without',
#   'sugar',
#   'or',
#   'milk',
#   'and',
#   'it',
#   'ha',
#   'a',
#   'pleasant',
#   'br',
#   'br',
#   'the',
#   'price',
#   'from',
#   'amazon',
#   'is',
#   'cheaper',
#   'than',
#   'my',
#   'local',
#   'grocery',
#   'store'],
#  ['one',
#   'reviewer',
#   'is',
#   'right',
#   'i',
#   'think',
#   'it',
#   'ha',
#   'some',
#   'herbal',
#   'smell',
#   'to',
#   'make',
#   'up',
#   'the',
#   'aroma'],
#  ['so',
#   'the',
#   'label',
#   'imperial',
#   'blend',
#   'kind',
#   'of',
#   'implied',
#   'the',
#   'br',
#   'br',
#   'i',
#   'am',
#   'not',
#   'exactly',
#   'a',
#   'black',
#   'tea',
#   'drinker',
#   'so',
#   'this',
#   'tea',
#   'is',
#   'a',
#   'surprise',
#   'and',
#   'affordable',
#   'too'],
#  ['i',
#   'usually',
#   'prefer',
#   'white',
#   'chinese',
#   'tea',
#   'like',
#   'white',
#   'peony',
#   'but',
#   'it',
#   'is',
#   'more',
#   'expensive',
#   'and',
#   'requires',
#   'lower',
#   'temperature',
#   'water'],
#  ['but',
#   'this',
#   'is',
#   'black',
#   'tea',
#   'and',
#   'this',
#   'aroma',
#   'kind',
#   'of',
#   'remind',
#   'me',
#   'the',
#   'of',
#   'white',
#   'tea'],
#  ['i', 'tried', 'a', 'variety', 'of', 'ahmad', 'tea'],
#  ['not',
#   'because',
#   'i',
#   'particularly',
#   'like',
#   'this',
#   'brand',
#   'but',
#   'they',
#   'are',
#   'just',
#   'easier',
#   'to',
#   'come',
#   'across'],
#  ['the',
#   'imperial',
#   'blend',
#   'i',
#   'believe',
#   'is',
#   'the',
#   'most',
#   'complex',
#   'yet',
#   'well',
#   'balanced',
#   'of',
#   'all',
#   'the',
#   'one',
#   'i',
#   'tried'],
#  ['it',
#   'full',
#   'body',
#   'like',
#   'a',
#   'good',
#   'cup',
#   'of',
#   'assam',
#   'which',
#   'by',
#   'no',
#   'mean',
#   'overpower',
#   'the',
#   'delightful',
#   'clean',
#   'taste',
#   'of',
#   'darjeerling',
#   'complete',
#   'with',
#   'a',
#   'long',
#   'lasting',
#   'note',
#   'of',
#   'bergamot'],
#  ['i', 'enjoy', 'it', 'best', 'in', 'the', 'evening'],
#  ['it',
#   'give',
#   'a',
#   'satisfying',
#   'and',
#   'relaxing',
#   'finish',
#   'to',
#   'a',
#   'busy',
#   'br',
#   'br',
#   'for',
#   'those',
#   'interested',
#   'in',
#   'the',
#   'specific',
#   'i',
#   'use',
#   'about',
#   '3',
#   'teaspoon',
#   'of',
#   'lose',
#   'tea',
#   'in',
#   'a',
#   'stainless',
#   'steel',
#   'infuser',
#   'in',
#   'a',
#   '16',
#   'oz',
#   'mug',
#   'let',
#   'it',
#   'steep',
#   'in',
#   '208f',
#   'water',
#   'for',
#   'min',
#   'take',
#   'the',
#   'infuser',
#   'out',
#   'and',
#   'drink',
#   'it',
#   'without',
#   'sugar',
#   'or',
#   'milk',
#   'to',
#   'savor',
#   'it',
#   'sophistication'],
#  ['i',
#   'have',
#   'tried',
#   'literally',
#   'dozen',
#   'of',
#   'tea',
#   'since',
#   'being',
#   'introduced',
#   'to',
#   'the',
#   'russian',
#   'custom',
#   'of',
#   'preparing',
#   'and',
#   'drinking',
#   'tea',
#   'and',
#   'the',
#   'ahmad',
#   'imperial',
#   'blend',
#   'is',
#   'probably',
#   'my',
#   'favorite',
#   'of',
#   'all',
#   'of',
#   'these',
#   'due',
#   'to',
#   'the',
#   'fact',
#   'that',
#   'it',
#   'is',
#   'equally',
#   'delicious',
#   'hot',
#   'or',
#   'iced'],
#  ['i',
#   'buy',
#   'the',
#   'a',
#   'needed',
#   'from',
#   'amazon',
#   'and',
#   'go',
#   'through',
#   'them',
#   'rapidly'],
#  ['my',
#   'family',
#   'love',
#   'it',
#   'and',
#   'my',
#   'friend',
#   'have',
#   'it',
#   'in',
#   'their',
#   'home',
#   'now',
#   'too',
#   'try',
#   'one',
#   'box',
#   'of',
#   'it',
#   'and',
#   'you',
#   'will',
#   'love',
#   'it',
#   'too'],
#  ['this', 'is', 'an', 'excellent', 'tea'],
#  ['one', 'of', 'the', 'best', 'i', 'have', 'ever', 'had'],
#  ['it',
#   'is',
#   'especially',
#   'great',
#   'when',
#   'you',
#   'prepare',
#   'it',
#   'with',
#   'a',
#   'samovar'],
#  ['herbal',
#   'additive',
#   'in',
#   'this',
#   'blend',
#   'destroy',
#   'real',
#   'tea',
#   'taste'],
#  ['it', 'is', 'only', 'for', 'people', 'who', 'like', 'herbal', 'taste'],
#  ['i', 'do'],
#  ['makes', 'a', 'tasty', 'super', 'easy', 'meal', 'fast'],
#  ['but',
#   'high',
#   'in',
#   'br',
#   'br',
#   'the',
#   'instruction',
#   'say',
#   'to',
#   'saute',
#   'the',
#   'veggie',
#   'first',
#   'but',
#   'i',
#   'recommend',
#   'cooking',
#   'the',
#   'chicken',
#   'first'],
#  ['the',
#   'chicken',
#   'take',
#   'longer',
#   'to',
#   'cook',
#   'and',
#   'the',
#   'raw',
#   'chicken',
#   'ontop',
#   'of',
#   'veggie',
#   'just',
#   'make',
#   'a',
#   'slimy',
#   'mess'],
#  ['i', 'made', 'it', 'with', 'snow', 'pea', 'and', 'carrot', 'only'],
#  ['i', 'dont', 'like', 'the', 'little', 'corn'],
#  ['added',
#   'some',
#   'red',
#   'pepper',
#   'flake',
#   'for',
#   'heat',
#   'and',
#   'served',
#   'ontop',
#   'of',
#   'rice'],
#  ['it', 'came', 'out', 'wonderful'],
#  ['dinner', 'on', 'the', 'table', 'in', 'le', 'than', '30mins'],
#  ['i',
#   'think',
#   'i',
#   'have',
#   'tried',
#   'just',
#   'about',
#   'every',
#   'bloody',
#   'mary',
#   'mixer',
#   'on',
#   'the',
#   'market',
#   'at',
#   'one',
#   'time',
#   'or',
#   'the',
#   'other'],
#  ['most', 'have', 'too', 'much', 'sugar', 'or', 'worst', 'corn', 'syrup'],
#  ['this',
#   'mixer',
#   'is',
#   'all',
#   'natural',
#   'ingredient',
#   'and',
#   'very',
#   'tasty'],
#  ['it', 'doe', 'have', 'a', 'little', 'kick'],
#  ['enjoy'],
#  ['might',
#   'be',
#   'a',
#   'little',
#   'spicy',
#   'for',
#   'some',
#   'but',
#   'this',
#   'stuff',
#   'rock'],
#  ['i',
#   'use',
#   'with',
#   'v8',
#   'for',
#   'a',
#   'milder',
#   'version',
#   'or',
#   'the',
#   'best',
#   'is',
#   'a',
#   'bloody',
#   'caesar',
#   'br',
#   'half',
#   'mix',
#   'half',
#   'clamato'],
#  ['took',
#   'me',
#   'one',
#   'or',
#   'two',
#   'to',
#   'get',
#   'used',
#   'to',
#   'the',
#   'pickle',
#   'taste'],
#  ['but',
#   'now',
#   'aim',
#   'hooked',
#   'and',
#   'have',
#   'to',
#   'keep',
#   'a',
#   'bottle',
#   'on',
#   'hand',
#   'this',
#   'candy',
#   'is',
#   'not',
#   'a',
#   'described'],
#  ['the',
#   'middle',
#   'is',
#   'almost',
#   'hard',
#   'it',
#   'is',
#   'not',
#   'a',
#   'silky',
#   'or',
#   'smooth',
#   'filling',
#   'a',
#   'br',
#   'looks',
#   'and',
#   'taste',
#   'like',
#   'it',
#   'way',
#   'past',
#   'it',
#   'expiration',
#   'br',
#   'would',
#   'never',
#   'reccommend',
#   'this'],
#  ['paid',
#   'a',
#   'good',
#   'chunk',
#   'of',
#   'cash',
#   'for',
#   'nothing',
#   'i',
#   'started',
#   'drinking',
#   'the',
#   'power',
#   'slim',
#   'tea',
#   'when',
#   'i',
#   'wa',
#   'on',
#   'the',
#   'hcg',
#   'diet',
#   'to',
#   'help',
#   'curb',
#   'craving'],
#  ['since',
#   'i',
#   'liked',
#   'it',
#   'so',
#   'well',
#   'i',
#   'tried',
#   'some',
#   'of',
#   'the',
#   'others',
#   'and',
#   'i',
#   'am',
#   'now',
#   'hooked'],
#  ['they',
#   'are',
#   'so',
#   'satisfying',
#   'that',
#   'i',
#   'drink',
#   'them',
#   'all',
#   'the',
#   'time'],
#  ['the',
#   'energy',
#   'give',
#   'you',
#   'that',
#   'extra',
#   'in',
#   'the',
#   'afternoon',
#   'that',
#   'help',
#   'keep',
#   'me',
#   'going',
#   'all',
#   'day',
#   'no',
#   'matter',
#   'how',
#   'long'],
#  ['i', 'trying', 'several', 'of', 'the', 'wu', 'yi', 'tea'],
#  ['i',
#   'like',
#   'this',
#   'one',
#   'particularly',
#   'because',
#   'of',
#   'the',
#   'subtle',
#   'citrus',
#   'taste'],
#  ['it',
#   'also',
#   'ha',
#   'a',
#   'natural',
#   'br',
#   'br',
#   'the',
#   'ingredient',
#   'include',
#   'organic',
#   'cliff',
#   'oolong',
#   'tea',
#   '700',
#   'mg',
#   'organic',
#   'black',
#   'tea',
#   '600',
#   'mg',
#   'organic',
#   'green',
#   'tea',
#   'extract',
#   '100',
#   'mg',
#   'proprietary',
#   'blend',
#   '600',
#   'mg',
#   'plus',
#   'some',
#   'ginseng',
#   'panax',
#   'orange',
#   'peel',
#   'lemon',
#   'grass',
#   'and',
#   'guarana'],
#  ['other',
#   'ingredients',
#   'natual',
#   'orange',
#   'and',
#   'citrus',
#   'br',
#   'br',
#   'my',
#   'goal',
#   'is',
#   'to',
#   'drink',
#   'more',
#   'tea',
#   'and',
#   'le',
#   'coffee'],
#  ['i',
#   'am',
#   'enjoying',
#   'trying',
#   'a',
#   'different',
#   'kind',
#   'of',
#   'tea',
#   'every',
#   'day'],
#  ['i', 'be', 'coming', 'back', 'to', 'this', 'one'],
#  ['i',
#   'can',
#   'not',
#   'live',
#   'without',
#   'this',
#   'citron',
#   'falksalt',
#   'it',
#   'is',
#   'wonderful',
#   'on',
#   'watermelon',
#   'fish',
#   'almost',
#   'any',
#   'food',
#   'requiring',
#   'salt',
#   'and',
#   'in',
#   'my',
#   'world',
#   'it',
#   'all',
#   'doe'],
#  ['just',
#   'try',
#   'it',
#   'on',
#   'red',
#   'juicy',
#   'watermelon',
#   'wonderful',
#   'experience'],
#  ['terrible'],
#  ['artificial',
#   'lemon',
#   'taste',
#   'like',
#   'pledge',
#   'lemon',
#   'furniture',
#   'polish'],
#  ['do', 'do', 'this', 'to', 'yourself'],
#  ['just',
#   'use',
#   'plain',
#   'flake',
#   'salt',
#   'and',
#   'some',
#   'fresh',
#   'grated',
#   'lemon',
#   'zest'],
#  ['these', 'thing', 'are', 'huge'],
#  ['i',
#   'love',
#   'the',
#   'way',
#   'the',
#   'crystal',
#   'crunch',
#   'and',
#   'the',
#   'flavor',
#   'is',
#   'not',
#   'too',
#   'overpowering',
#   'or',
#   'too',
#   'subtle'],
#  ['this',
#   'lemony',
#   'flavor',
#   'is',
#   'my',
#   'favorite',
#   'it',
#   'good',
#   'on',
#   'almost',
#   'everything'],
#  ['you',
#   'have',
#   'plenty',
#   'of',
#   'flavored',
#   'salt',
#   'for',
#   'a',
#   'long',
#   'time',
#   'if',
#   'you',
#   'buy',
#   'this'],
#  ['the',
#   'taste',
#   'of',
#   'these',
#   'white',
#   'cheddar',
#   'flat',
#   'bread',
#   'is',
#   'like',
#   'a',
#   'regular',
#   'cracker',
#   'which',
#   'is',
#   'not',
#   'bad',
#   'except',
#   'that',
#   'i',
#   'bought',
#   'them',
#   'because',
#   'i',
#   'wanted',
#   'a',
#   'cheese',
#   'br',
#   'br',
#   'what',
#   'wa',
#   'a',
#   'huge',
#   'disappointment'],
#  ['how', 'misleading', 'the', 'packaging', 'of', 'the', 'box', 'is'],
#  ['the',
#   'photo',
#   'on',
#   'the',
#   'box',
#   'i',
#   'bought',
#   'these',
#   'in',
#   'store',
#   'make',
#   'it',
#   'look',
#   'like',
#   'it',
#   'is',
#   'full',
#   'of',
#   'long',
#   'flatbread',
#   'expanding',
#   'the',
#   'length',
#   'and',
#   'width',
#   'of',
#   'the',
#   'box'],
#  ['wrong'],
#  ['the',
#   'plastic',
#   'tray',
#   'that',
#   'hold',
#   'the',
#   'cracker',
#   'is',
#   'about',
#   '2',
#   'smaller',
#   'all',
#   'around',
#   'leaving',
#   'you',
#   'with',
#   'about',
#   '15',
#   'or',
#   'so',
#   'small',
#   'br',
#   'br',
#   'what',
#   'is',
#   'also',
#   'bad',
#   'about',
#   'this',
#   'is',
#   'that',
#   'the',
#   'company',
#   'state',
#   'they',
#   'use',
#   'biodegradable',
#   'and',
#   'packaging'],
#  ['fail'],
#  ...]

# %% [markdown]
# # WORD2VEC WORD EMBEDDINGS

# %%
model1=Word2Vec(t_data,min_count=1,vector_size=100,window=5,sg=0)
model2=Word2Vec(t_data,min_count=1,vector_size=100,window=5,sg=1)

# %%
#print('similarity between two words is ',model1.wv.similarity('highly','recommend'))
print('similarity between two words is ',model2.wv.similarity('highly','recommend'))
# Out:
# similarity between two words is  0.76407975

# %%
print('similarity between two words is ',model2.wv.similarity('tea','coffee'))
# Out:
# similarity between two words is  0.6649142

# %%
embedding = model2.wv['recommend']
print(f"Embedding for '{'recommend'}':\n{embedding}")
# Out:
# Embedding for 'recommend':
# [-0.16022879  0.6100218  -0.6670594  -0.21541446  0.59396505 -1.0801429
#  -0.20466153  0.24183685 -0.35452947 -0.11492071 -0.16701737 -0.18189973
#   0.5329217   0.5166201  -0.19892967  0.05349647  0.5377557  -0.54798484
#  -0.46116865 -1.2228719   0.55066127 -0.06453476 -0.07074429 -0.5694862
#  -0.6749693  -0.21089794  0.04380779 -0.22135216  0.01930305 -0.3691598
#   0.20395939 -0.14895543 -0.08248416 -0.3918958  -0.48220932  0.66629785
#  -0.46459302 -0.39216313 -0.27857852 -0.09691444  0.31442937 -0.85412055
#  -0.31971946  0.46656263  0.20542261  0.7653585  -0.5495336  -0.44040617
#   0.46507     0.6428148  -0.7099511   0.89769727 -0.25850528 -0.3123817
#   0.31820756  0.01505894 -0.12587167 -0.1564192   0.14739816  0.29157814
#  -0.3443058  -0.12393466 -0.24032171  0.14848566 -0.2360329   0.02989671
#   0.18959261  0.77095777 -0.00904361  0.5511399  -0.2613861   0.25821736
#   0.4511841  -0.30431008  0.12031422  0.18354669  0.3189217  -0.37131593
#   0.34080085 -0.3910523  -0.54104245  0.476989   -0.74754524 -0.24968894
#  -0.22087745 -0.5196582   0.02079953  0.19231516  0.52059335  0.32380852
#  -0.12558529 -0.10826176  0.13770704  0.5415407   0.58175266 -0.00911981
#  -0.19812042 -0.26050344  0.4301777   0.00223527]

# %% [markdown]
# **Semantic Textual Similarity**

# %%
from sklearn.metrics.pairwise import cosine_similarity
import numpy as np



sentence1 = "This Product is highly recommended."
sentence2 = "I like the product."


from nltk.tokenize import word_tokenize

def tokenize_and_preprocess_text(sentence):
    tokens = word_tokenize(sentence)
    tokens=[lemmatizer.lemmatize(token) for token in tokens]
    tokens = [token.lower() for token in tokens if token.isalnum()]

    return tokens


tokens1 = tokenize_and_preprocess_text(sentence1)
tokens2 = tokenize_and_preprocess_text(sentence2)

def get_sentence_vector(tokens, model):
    # Filter out tokens that are not in the model's vocabulary
    if not tokens:
        return np.zeros(model.vector_size)
    return np.mean(model.wv[tokens], axis=0)

vector1 = get_sentence_vector(tokens1, model2)
vector2 = get_sentence_vector(tokens2, model2)

# Calculate the cosine similarity between the two sentence vectors
similarity = cosine_similarity([vector1], [vector2])[0][0]

print(f"Cosine Similarity: {similarity}")
# Out:
# Cosine Similarity: 0.7774705290794373

# %% [markdown]
# T_SNE

# %%
import numpy as np
from sklearn.manifold import TSNE
import matplotlib.pyplot as plt
from gensim.models import Word2Vec


# Get word vectors and corresponding words from the model
words = list(model2.wv.index_to_key)
words=words[:100]
word_vectors = [model2.wv[word] for word in words]

# Convert word_vectors to a NumPy array
word_vectors = np.array(word_vectors)

# Perform t-SNE dimensionality reduction
tsne = TSNE(n_components=2, random_state=42)
word_vectors_2d = tsne.fit_transform(word_vectors)

# Create a scatter plot
plt.figure(figsize=(12, 8))
plt.scatter(word_vectors_2d[:, 0], word_vectors_2d[:, 1], marker='o', s=30)

# Label some points for reference (optional)
sample_words = words[:100]  # Label the first 5 words from your list
for word, (x, y) in zip(sample_words, word_vectors_2d[:100]):
    plt.annotate(word, (x, y))

# # Label some points for reference (optional)
# sample_words = ['word1', 'word2', 'word3']  # Replace with words from your model
# for word in sample_words:
#     idx = words.index(word)
#     plt.annotate(word, (word_vectors_2d[idx, 0], word_vectors_2d[idx, 1]))

# Show the plot
plt.title('t-SNE Plot of Word2Vec Embeddings')
plt.grid(True)
plt.show()

# %% [markdown]
# # GLOVE WORD EMBEDDINGS

# %%
import os
import urllib.request
import matplotlib.pyplot as plt
from scipy import spatial
from sklearn.manifold import TSNE
import numpy as np

# %%
# code for Glove word embedding
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
import numpy as np




# !wget http://nlp.stanford.edu/data/glove.6B.zip
# !unzip glove*.zip
# Out:
# --2023-10-10 16:47:01--  http://nlp.stanford.edu/data/glove.6B.zip
# Resolving nlp.stanford.edu (nlp.stanford.edu)... 171.64.67.140
# Connecting to nlp.stanford.edu (nlp.stanford.edu)|171.64.67.140|:80... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://nlp.stanford.edu/data/glove.6B.zip [following]
# --2023-10-10 16:47:01--  https://nlp.stanford.edu/data/glove.6B.zip
# Connecting to nlp.stanford.edu (nlp.stanford.edu)|171.64.67.140|:443... connected.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: https://downloads.cs.stanford.edu/nlp/data/glove.6B.zip [following]
# --2023-10-10 16:47:02--  https://downloads.cs.stanford.edu/nlp/data/glove.6B.zip
# Resolving downloads.cs.stanford.edu (downloads.cs.stanford.edu)... 171.64.64.22
# Connecting to downloads.cs.stanford.edu (downloads.cs.stanford.edu)|171.64.64.22|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 862182613 (822M) [application/zip]
# Saving to: ‘glove.6B.zip’
#
# glove.6B.zip        100%[===================>] 822.24M  5.03MB/s    in 2m 40s
#
# 2023-10-10 16:49:42 (5.14 MB/s) - ‘glove.6B.zip’ saved [862182613/862182613]
#
# Archive:  glove.6B.zip
#   inflating: glove.6B.50d.txt
#   inflating: glove.6B.100d.txt
#   inflating: glove.6B.200d.txt
#   inflating: glove.6B.300d.txt

# %%
# create the dict.
x=[token for token in list(i for i in t_data)]
tokenizer = Tokenizer()
tokenizer.fit_on_texts(x)

# number of unique words in dict.
print("Number of unique words in dictionary=",
	len(tokenizer.word_index))
print("Dictionary is = ", tokenizer.word_index)
# Out:
# Number of unique words in dictionary= 35605
# Dictionary is =  {'the': 1, 'i': 2, 'a': 3, 'and': 4, 'it': 5, 'to': 6, 'of': 7, 'is': 8, 'this': 9, 'br': 10, 'for': 11, 'in': 12, 'that': 13, 'my': 14, 'but': 15, 'you': 16, 'with': 17, 'have': 18, 'not': 19, 'are': 20, 'wa': 21, 'they': 22, 'like': 23, 'on': 24, 'so': 25, 'these': 26, 'them': 27, 'taste': 28, 'good': 29, 'be': 30, 'one': 31, 'flavor': 32, 'at': 33, 'or': 34, 'product': 35, 'just': 36, 'if': 37, 'very': 38, 'do': 39, 'great': 40, 'can': 41, 'love': 42, 'coffee': 43, 'all': 44, 'tea': 45, 'we': 46, 'from': 47, 'would': 48, 'when': 49, 'more': 50, 'ha': 51, 'had': 52, 'will': 53, 'me': 54, 'food': 55, 'get': 56, 'out': 57, 'than': 58, 'dog': 59, 'make': 60, 'other': 61, 'no': 62, 'some': 63, 'really': 64, 'about': 65, 'only': 66, 'up': 67, 'time': 68, 'too': 69, 'much': 70, 'an': 71, 'there': 72, 'your': 73, 'because': 74, 'bag': 75, 'also': 76, 'were': 77, 'little': 78, 'use': 79, 'amazon': 80, 'price': 81, 'what': 82, 'he': 83, 'chocolate': 84, 'did': 85, 'buy': 86, 'treat': 87, 'tried': 88, 'best': 89, 'which': 90, 'been': 91, 'even': 92, 'am': 93, 'she': 94, 'find': 95, 'try': 96, 'by': 97, 'better': 98, 'after': 99, 'doe': 100, 'well': 101, 'now': 102, 'drink': 103, 'any': 104, 'eat': 105, 'first': 106, 'cup': 107, 'store': 108, 'their': 109, 'our': 110, 'could': 111, 'box': 112, 'day': 113, 'water': 114, 'sugar': 115, 'brand': 116, 'her': 117, 'then': 118, 'year': 119, 'chip': 120, 'found': 121, 'cat': 122, 'again': 123, 'sweet': 124, 'go': 125, 'used': 126, 'give': 127, 'made': 128, 'way': 129, 'bought': 130, 'think': 131, 'mix': 132, 'bit': 133, 'thing': 134, 'two': 135, 'say': 136, 'know': 137, 'who': 138, 'favorite': 139, 'still': 140, 'over': 141, 'since': 142, 'recommend': 143, 'order': 144, 'want': 145, 'lot': 146, 'most': 147, 'got': 148, 'hot': 149, '2': 150, 'many': 151, 'delicious': 152, 'nice': 153, 'how': 154, 'snack': 155, 'pack': 156, 'bar': 157, 'keep': 158, 'never': 159, 'ingredient': 160, 'add': 161, 'work': 162, 'into': 163, 'something': 164, 'ca': 165, 'come': 166, 'without': 167, 'before': 168, 'every': 169, 'need': 170, 'few': 171, 'review': 172, 'right': 173, 'organic': 174, 'same': 175, 'always': 176, 'while': 177, 'milk': 178, 'free': 179, 'le': 180, 'however': 181, 'quality': 182, 'salt': 183, 'easy': 184, 'package': 185, 'stuff': 186, 'his': 187, 'different': 188, 'small': 189, 'calorie': 190, 'perfect': 191, 'enough': 192, 'healthy': 193, 'put': 194, 'ever': 195, 'take': 196, 'ordered': 197, 'regular': 198, 'old': 199, '3': 200, 'sure': 201, 'bad': 202, 'back': 203, 'strong': 204, 'eating': 205, 'though': 206, 'size': 207, 'enjoy': 208, 'definitely': 209, 'here': 210, 'buying': 211, 'hard': 212, 'problem': 213, 'using': 214, 'green': 215, 'those': 216, 'thought': 217, 'month': 218, 'fresh': 219, 'chicken': 220, 'each': 221, 'off': 222, 'see': 223, 'whole': 224, 'down': 225, 'far': 226, 'oil': 227, 'high': 228, 'smell': 229, 'pretty': 230, 'butter': 231, 'being': 232, 'both': 233, 'dark': 234, 'last': 235, 'looking': 236, 'long': 237, 'natural': 238, 'big': 239, 'texture': 240, 'people': 241, 'fat': 242, 'happy': 243, 'tasty': 244, 'local': 245, 'popcorn': 246, 'actually': 247, 'him': 248, 'another': 249, 'may': 250, 'peanut': 251, 'quite': 252, '1': 253, 'going': 254, 'should': 255, 'feel': 256, 'tasted': 257, 'look': 258, 'new': 259, '5': 260, 'shipping': 261, 'purchase': 262, 'almost': 263, 'through': 264, 'sauce': 265, 'low': 266, 'real': 267, 'coconut': 268, 'anything': 269, 'item': 270, 'highly': 271, 'juice': 272, '4': 273, 'own': 274, 'excellent': 275, 'per': 276, 'wonderful': 277, 'blend': 278, 'star': 279, 'around': 280, 'purchased': 281, 'bottle': 282, 'variety': 283, 'amount': 284, 'ginger': 285, 'case': 286, 'trying': 287, 'worth': 288, 'added': 289, 'diet': 290, 'half': 291, 'tasting': 292, 'protein': 293, 'potato': 294, 'probably': 295, 'expensive': 296, 'kind': 297, 'getting': 298, 'cooky': 299, 'company': 300, 'help': 301, 'bread': 302, 'having': 303, 'as': 304 ...

# %%
def embedding_for_vocab(filepath, word_index,
						embedding_dim):
	vocab_size = len(word_index) + 1

	# Adding again 1 because of reserved 0 index
	embedding_matrix_vocab = np.zeros((vocab_size,
									embedding_dim))

	with open(filepath, encoding="utf8") as f:
		for line in f:
			word, *vector = line.split()
			if word in word_index:
				idx = word_index[word]
				embedding_matrix_vocab[idx] = np.array(
					vector, dtype=np.float32)[:embedding_dim]

	return embedding_matrix_vocab


# matrix for vocab: word_index
embedding_dim = 50
embedding_matrix_vocab = embedding_for_vocab(
	'/content/glove.6B.50d.txt', tokenizer.word_index,
embedding_dim)

print("Dense vector for first word 'the' is => ",
	embedding_matrix_vocab[1])
# Out:
# Dense vector for first word 'the' is =>  [ 4.18000013e-01  2.49679998e-01 -4.12420005e-01  1.21699996e-01
#   3.45270008e-01 -4.44569997e-02 -4.96879995e-01 -1.78619996e-01
#  -6.60229998e-04 -6.56599998e-01  2.78430015e-01 -1.47670001e-01
#  -5.56770027e-01  1.46579996e-01 -9.50950012e-03  1.16579998e-02
#   1.02040000e-01 -1.27920002e-01 -8.44299972e-01 -1.21809997e-01
#  -1.68009996e-02 -3.32789987e-01 -1.55200005e-01 -2.31309995e-01
#  -1.91809997e-01 -1.88230002e+00 -7.67459989e-01  9.90509987e-02
#  -4.21249986e-01 -1.95260003e-01  4.00710011e+00 -1.85939997e-01
#  -5.22870004e-01 -3.16810012e-01  5.92130003e-04  7.44489999e-03
#   1.77780002e-01 -1.58969998e-01  1.20409997e-02 -5.42230010e-02
#  -2.98709989e-01 -1.57490000e-01 -3.47579986e-01 -4.56370004e-02
#  -4.42510009e-01  1.87849998e-01  2.78489990e-03 -1.84110001e-01
#  -1.15139998e-01 -7.85809994e-01]

# %%
from sklearn.metrics.pairwise import cosine_similarity

word_to_find = 'good'
if word_to_find in tokenizer.word_index:
    idx = tokenizer.word_index[word_to_find]
    # Access the word embedding vector for 'good'
    embedding_of_good = embedding_matrix_vocab[idx]
    print(f"Word embedding vector for '{word_to_find}':\n{embedding_of_good}")
else:
    print(f"'{word_to_find}' not found in the vocabulary.")

# Calculate similarity between two words (e.g., 'good' and 'excellent')
word1 = 'good'
word2 = 'excellent'
if word1 in tokenizer.word_index and word2 in tokenizer.word_index:
    idx1 = tokenizer.word_index[word1]
    idx2 = tokenizer.word_index[word2]
    embedding1 = embedding_matrix_vocab[idx1]
    embedding2 = embedding_matrix_vocab[idx2]
    similarity = cosine_similarity([embedding1], [embedding2])[0][0]
    print(f"Similarity between '{word1}' and '{word2}': {similarity}")
else:
    print("One or both of the words not found in the vocabulary.")
# Out:
# Word embedding vector for 'good':
# [-3.55859995e-01  5.21300018e-01 -6.10700011e-01 -3.01310003e-01
#   9.48620021e-01 -3.15389991e-01 -5.98309994e-01  1.21880002e-01
#  -3.19430009e-02  5.56949973e-01 -1.06210001e-01  6.33989990e-01
#  -4.73399997e-01 -7.58949965e-02  3.82470012e-01  8.15690011e-02
#   8.22139978e-01  2.22200006e-01 -8.37639999e-03 -7.66200006e-01
#  -5.62529981e-01  6.17590010e-01  2.02920005e-01 -4.85979989e-02
#   8.78149986e-01 -1.65489995e+00 -7.74179995e-01  1.54349998e-01
#   9.48230028e-01 -3.95200014e-01  3.73020005e+00  8.28549981e-01
#  -1.41039997e-01  1.63950007e-02  2.11150005e-01 -3.60849984e-02
#  -1.55870005e-01  8.65830004e-01  2.63090014e-01 -7.10150003e-01
#  -3.67700011e-02  1.82819995e-03 -1.77039996e-01  2.70319998e-01
#   1.10260002e-01  1.41330004e-01 -5.73219992e-02  2.72069991e-01
#   3.13050002e-01  9.27709997e-01]
# Similarity between 'good' and 'excellent': 0.8061552559026371

# %% [markdown]
# STS

# %%
from sklearn.metrics.pairwise import cosine_similarity
import numpy as np



sentence1 = "This Product is highly recommended."
sentence2 = "I like the product."


from nltk.tokenize import word_tokenize

def tokenize_and_preprocess_text(sentence):
    tokens = word_tokenize(sentence)
    tokens=[lemmatizer.lemmatize(token) for token in tokens]
    tokens = [token.lower() for token in tokens if token.isalnum()]

    return tokens


tokens1 = tokenize_and_preprocess_text(sentence1)
tokens2 = tokenize_and_preprocess_text(sentence2)

def get_sentence_vector(tokens, model):
    # Filter out tokens that are not in the model's vocabulary
    if not tokens:
        return np.zeros(model.vector_size)
    return np.mean(list(embedding_matrix_vocab[tokenizer.word_index[word]] for word in tokens), axis=0)

vector1 = get_sentence_vector(tokens1, model2)
vector2 = get_sentence_vector(tokens2, model2)

# Calculate the cosine similarity between the two sentence vectors
similarity = cosine_similarity([vector1], [vector2])[0][0]

print(f"Cosine Similarity: {similarity}")
# Out:
# Cosine Similarity: 0.8792564659981774

# %%
# Load pre-trained GloVe embeddings
embedding_path = '/content/glove.6B.50d.txt'
word_embeddings = {}
with open(embedding_path, 'r', encoding='utf8') as f:
    for line in f:
        values = line.split()
        word = values[0]
        vector = np.asarray(values[1:], dtype='float32')
        word_embeddings[word] = vector

# Get word vectors and corresponding words from the GloVe model
words = list(tokenizer.word_index.keys())
words = words[200:300]  # Limit to the 100 words for the example
word_vectors = [embedding_matrix_vocab[tokenizer.word_index[word]] for word in words]

# Convert word_vectors to a NumPy array
word_vectors = np.array(word_vectors)

# Perform t-SNE dimensionality reduction
tsne = TSNE(n_components=2, random_state=42)
word_vectors_2d = tsne.fit_transform(word_vectors)

# Create a scatter plot
plt.figure(figsize=(12, 8))
plt.scatter(word_vectors_2d[:, 0], word_vectors_2d[:, 1], marker='o', s=30)

# Label points with word labels
for word, (x, y) in zip(words, word_vectors_2d):
    plt.text(x, y, word, fontsize=10, ha='center', va='bottom')

# Show the plot
plt.title('t-SNE Plot of GloVe Embeddings with Word Labels')
plt.grid(True)
plt.show()

# %% [markdown]
# # FASTTEXT WORD EMBEDDINGS

# %%
from gensim.models import FastText

model3=FastText(t_data,min_count=1,vector_size=100,window=5,sg=1, workers = 4, min_n = 1, max_n = 4)

# %%
print('similarity between two words is ',model3.wv.similarity('highly','recommend'))
print('similarity between two words is ',model3.wv.similarity('good','excellent'))
print('similarity between two words is ',model3.wv.similarity('tea','coffee'))
# Out:
# similarity between two words is  0.7936025
# similarity between two words is  0.73520255
# similarity between two words is  0.75080335

# %% [markdown]
# STS

# %%
from sklearn.metrics.pairwise import cosine_similarity
import numpy as np



sentence1 = "This Product is highly recommended."
sentence2 = "I like the product."


from nltk.tokenize import word_tokenize

def tokenize_and_preprocess_text(sentence):
    tokens = word_tokenize(sentence)
    tokens=[lemmatizer.lemmatize(token) for token in tokens]
    tokens = [token.lower() for token in tokens if token.isalnum()]

    return tokens


tokens1 = tokenize_and_preprocess_text(sentence1)
tokens2 = tokenize_and_preprocess_text(sentence2)

def get_sentence_vector(tokens, model):
    # Filter out tokens that are not in the model's vocabulary
    if not tokens:
        return np.zeros(model.vector_size)
    return np.mean(model.wv[tokens], axis=0)

vector1 = get_sentence_vector(tokens1, model3)
vector2 = get_sentence_vector(tokens2, model3)

# Calculate the cosine similarity between the two sentence vectors
similarity = cosine_similarity([vector1], [vector2])[0][0]

print(f"Cosine Similarity: {similarity}")
# Out:
# Cosine Similarity: 0.8270913362503052

# %%
# Get word vectors and corresponding words from the model
words = list(model3.wv.index_to_key)
words=words[200:300]
word_vectors = [model3.wv[word] for word in words]

# Convert word_vectors to a NumPy array
word_vectors = np.array(word_vectors)

# Perform t-SNE dimensionality reduction
tsne = TSNE(n_components=2, random_state=42)
word_vectors_2d = tsne.fit_transform(word_vectors)

# Create a scatter plot
plt.figure(figsize=(12, 8))
plt.scatter(word_vectors_2d[:, 0], word_vectors_2d[:, 1], marker='o', s=30)

# Label some points for reference (optional)
sample_words = words[:100]  # Label the first 5 words from your list
for word, (x, y) in zip(sample_words, word_vectors_2d[:100]):
    plt.annotate(word, (x, y))



# Show the plot
plt.title('t-SNE Plot of Word2Vec Embeddings')
plt.grid(True)
plt.show()
